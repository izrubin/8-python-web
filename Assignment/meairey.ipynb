# %% [markdown]
# # Notebook 8.1 RESTful GBIF
#
# This notebook will introduce you to methods for parsing data from the web by accessing websites that have RESTful APIs. In the next notebook we will continue to other methods for parsing data from the web as well.
#
# These notebook will involve two core aspects: (1) Working with RESTful APIs, which we discussed briefly in lecture; and (2) Parsing HTML text. The first is much easier since the data that we query from the web is returned in a form that is easy to interpret and *meant* to be parsed and analyzed, whereas the second way requires us to learn a little about how the internet works, which is also useful stuff to know. So let's get started. You'll need to install the two libraries below.

# %%
# conda install beautifulsoup4
# conda install requests

# %%
import toyplot
import requests
import pandas as pd

# %% [markdown]
# ### The design of REST APIs.
# The idea behind REST APIs is that data on a server (like a webpage) can be accessed with a consistent type of argument in the form of a URL, to query data which will then be returned in a form that is easy to analyze (usually json or xml), as opposed to being returned in messy HTML that needs to be parsed. Many websites have REST APIs, but some are much easier to use than others.

# %% [markdown]
# ### Limits
# Many REST APIs have limits on the way that you can use them. For example, the REST APIs for Twitter, GitHub, and Reddit require that you login in order to access data, and some sites will throttle how many requests you can make per hour. Although usually sites with a REST API are intended to be searched, the tools we will learn here can be used to search almost any website. It is important to know that some sites will intentionally block you if you try too aggressively to scrape data from them. For example, google scholar and genbank both have limits on the number of queries you can make per hour.

# %% [markdown]
# ### Good REST APIs
# A good REST API will have good directions for its usage. Two very good examples are the [USDA Bison API](https://bison.usgs.gov/#api) and the [Global Biodiversity Information Facility (GBIF) API](https://www.gbif.org/developer/summary). We'll focus on the latter in this notebook. The GBIF database is an international effort to collect all observation data on plants, animals, and fungi into a single place where it can be searched. It is actually a conglomeration of many separate databases, with data from museums and similar institutions all over the world. These APIs are free to use but request that you cite them if the data is used in a publication eventually.

# %% [markdown]
# ### What does GBIF do?
# GBIF can be used to find specimen collection records, or other types of observation data, stored in museum type databases. The website offers a convenient way to request taxa by name, and to select specific research criteria. For example, if we wanted to find all specimens of bumblebees (genus *Bombus*) that were collected between 1910 and 1920 we could request this through the website. It will draw a nice map with their locations and you can download a table with coordinates of where they were collected. This is actually one of the best databases around, since it organizes the data quite easily for you to download, but nevertheless, we'll use it as our example to learn REST APIs.
#
# Even though GBIF has a very nice web interface, it is obviously often more efficient to be able to query this database programmatically, instead of having to type each name we wish to search, and click on several buttons. This can provide a much more powerful way of applying filters over many different types of searches. That is the idea behind REST APIs and the reason why GBIF provides one.

# %% [markdown]
# ### The base-url
# The base URL is the web address of the API. This is simply a string that we wil add arguments to in order to request particular types of data be returned to use from the database. For GBIF this is the following, which we'll store as a string for now. This base-url address is given to us right at the top of the [GBIF API documentation](https://www.gbif.org/developer/occurrence). You can see that it looks much like any other web address.

# %%
baseurl = "http://api.gbif.org/v1/occurrence/search?"

# %% [markdown]
# ### How to query GBIF
# As you can see in the URL below, an API query just has additional arguments added to the baseurl. The string below searches for records with the name *Bombus*, which is the genus for bumblebees. We've added just the 'query' option 'q' and the name. We'll see next how to make more complex queries. But first, copy the URL below (without the quotation marks around it) and paste it into a web browser. This will show you what the returned data looks like. It might look a bit different depending on which browser you are using (I recommend using firefox or chrome) but the underlying data is the same, and is called JSON data.

# %%
search_url = "http://api.gbif.org/v1/occurrence/search?q=Bombus"

# %% [markdown]
# ### JSON format
# We will be using the `requests` library to get data from online, but before we do, let's talk a bit about how the data will be structured so we know what to expect. The data that you should see in your browser now is called JSON formatted data.  You'll notice that this format is almost identical to what a Python dictionary looks like. It is composed of key:value pairs. This will make it particularly easy to work with.

# %% [markdown]
# ### Requests
#
# [Documentation](http://docs.python-requests.org/en/master/user/quickstart/)
#
# The `requests` package work a lot like an automated web browser. We've used `requests` briefly in the past but now we'll start to use it more effectively. The main function we will call is `.get()`, which will send a GET command to the web address and return a Response Class object. We will then access attributes and functions of the Response instance to see if our request worked, and to parse the resulting text from it. Let's try this on our `search_url` string defined above.

# %%
# create a Response instance from a request
response = requests.get(search_url)

# %%
# check that your request worked (200 = worked; other codes No))
response.status_code
# Out:
# 200

# %%
# this would return the error message if it didn't work (else None)
response.raise_for_status()

# %% [markdown]
# ### Parse a Response
# Before when we've used `requests` we've parsed the results as plain text, since it was usually in a format that was easiest to work with as a string. In this case, we are going to access the data a bit differently, by instead  accessing it in JSON format. This is easily available from the object just like text is. The first is not very easily readable or parseable, whereas the second can be accessed and searched more easily.

# %%
# first 500 characters of the .text string
response.text[:500]
# Out:
# '{"offset":0,"limit":20,"endOfRecords":false,"count":1048304,"results":[{"key":131330107,"datasetKey":"86aba78e-f762-11e1-a439-00145eb45e9a","publishingOrgKey":"8595cd50-87c0-11dc-bb35-b8a03c50a862","publishingCountry":"BR","protocol":"DIGIR","lastCrawled":"2013-09-07T07:05:27.000+0000","crawlId":1,"extensions":{},"basisOfRecord":"PRESERVED_SPECIMEN","taxonKey":1340307,"kingdomKey":1,"phylumKey":54,"classKey":216,"orderKey":1457,"familyKey":4334,"genusKey":1340278,"speciesKey":1340307,"scientific'

# %%
# or, get results as a dictionary (JSON converted)
rdict = response.json()

# get some quick info on the dictionary items
list(rdict.keys())
# Out:
# ['offset', 'limit', 'endOfRecords', 'count', 'results', 'facets']

# %% [markdown]
# ### Parsing the results
# In GBIF our response can be parsed into a dictionary object using the JSON format, and this as six keys shown above. These are explained in the API docs, and correspond to information about what records are available for our query. However, it did not return *all* of the data for those records to us yet. That would be too easy. Instead, databases usually have limits on the amount of data from each request as a way of limiting the bandwidth they will need for sending the data, and to make it faster. For GBIF the default number, shown under the "limit" key, is 20. And the default starting position, shown under "offset" is 0. The total number of records is in "count". So for *Bombus*, as we show below, there are 1,048,303 records, but on records 1-20 were returned to us so far.

# %%
## how many records are there for this query
rdict["count"]
# Out:
# 1048304

# %%
## how many records were returned
rdict["limit"]
# Out:
# 20

# %%
## starting from which record
rdict["offset"]
# Out:
# 0

# %% [markdown]
# ### So where's the data?
# It's stored under the `results` variable, and is returned as a list of dictionaries, where each dictionary is a record with lots of information. Below I show the first record from our search.

# %%
# here is the first record, it's also a dictionary
rdict["results"][0]
# Out:
# {'basisOfRecord': 'PRESERVED_SPECIMEN',
#  'catalogNumber': '6416',
#  'class': 'Insecta',
#  'classKey': 216,
#  'collectionCode': 'CEPANN',
#  'continent': 'SOUTH_AMERICA',
#  'country': 'Brazil',
#  'countryCode': 'BR',
#  'crawlId': 1,
#  'datasetKey': '86aba78e-f762-11e1-a439-00145eb45e9a',
#  'decimalLatitude': 0.0,
#  'decimalLongitude': 0.0,
#  'extensions': {},
#  'facts': [],
#  'family': 'Apidae',
#  'familyKey': 4334,
#  'gbifID': '131330107',
#  'genericName': 'Bombus',
#  'genus': 'Bombus',
#  'genusKey': 1340278,
#  'geodeticDatum': 'WGS84',
#  'identifiers': [],
#  'institutionCode': 'USP',
#  'issues': ['ZERO_COORDINATE',
#   'GEODETIC_DATUM_ASSUMED_WGS84',
#   'COUNTRY_COORDINATE_MISMATCH'],
#  'key': 131330107,
#  'kingdom': 'Animalia',
#  'kingdomKey': 1,
#  'lastCrawled': '2013-09-07T07:05:27.000+0000',
#  'lastInterpreted': '2018-02-04T02:00:19.037+0000',
#  'license': 'http://creativecommons.org/licenses/by/4.0/legalcode',
#  'order': 'Hymenoptera',
#  'orderKey': 1457,
#  'phylum': 'Arthropoda',
#  'phylumKey': 54,
#  'protocol': 'DIGIR',
#  'publishingCountry': 'BR',
#  'publishingOrgKey': '8595cd50-87c0-11dc-bb35-b8a03c50a862',
#  'recordedBy': '-',
#  'relations': [],
#  'scientificName': 'Bombus morio (Swederus, 1787)',
#  'species': 'Bombus morio',
#  'speciesKey': 1340307,
#  'specificEpithet': 'morio',
#  'taxonKey': 1340307,
#  'taxonRank': 'SPECIES'}

# %%
# or to see it prettier, convert records to a DataFrame
pd.DataFrame(rdict["results"]).head()
# Out:
#         basisOfRecord catalogNumber    class  classKey collectionCode  \
# 0  PRESERVED_SPECIMEN          6416  Insecta       216         CEPANN
# 1  PRESERVED_SPECIMEN          9002  Insecta       216          CEMeC
# 2             UNKNOWN         43781  Insecta       216    2007_Mongol
# 3  PRESERVED_SPECIMEN         91583  Insecta       216            ZEN
# 4  PRESERVED_SPECIMEN         94807  Insecta       216            ZEN
#
#        continent country countryCode    county  crawlId    ...     \
# 0  SOUTH_AMERICA  Brazil          BR       NaN        1    ...
# 1            NaN  Brazil          BR  Milagres        1    ...
# 2            NaN     NaN        None       NaN       12    ...
# 3            NaN     NaN        None       NaN       17    ...
# 4            NaN     NaN        None       NaN       17    ...
#
#                        publishingOrgKey  recordedBy  relations  \
# 0  8595cd50-87c0-11dc-bb35-b8a03c50a862           -         []
# 1  8595cd50-87c0-11dc-bb35-b8a03c50a862         NaN         []
# 2  be11c6a0-7cf5-11dc-92cb-b8a03c50a862         NaN         []
# 3  4c415e40-1e21-11de-9e40-a0d6ecebb8bf         NaN         []
# 4  4c415e40-1e21-11de-9e40-a0d6ecebb8bf         NaN         []
#
#                   scientificName             species speciesKey  \
# 0  Bombus morio (Swederus, 1787)        Bombus morio  1340307.0
# 1  Bombus morio (Swederus, 1787)        Bombus morio  1340307.0
# 2    Bombus margreiteri Skorikov  Bombus margreiteri  9055570.0
# 3         Bombus Latreille, 1802                 NaN        NaN
# 4         Bombus Latreille, 1802                 NaN        NaN
#
#    specificEpithet stateProvince taxonKey taxonRank
# 0            morio           NaN  1340307   SPECIES
# 1            morio         Bahia  1340307   SPECIES
# 2      margreiteri           NaN  9055570   SPECIES
# 3              NaN           NaN  1340278     GENUS
# 4              NaN           NaN  1340278     GENUS
#
# [5 rows x 56 columns]

# %% [markdown]
# ### Building a request
# Here we add more arguments to further filter the results. To see which options are available, you can either look at the results from our existing calls so far, or you can read further into the API docs. Sometimes API docs will be incomplete though, so it can be useful to learn to try to infer which options are possible from looking at the results. A more complex search is accomplished by building a URL that has more key:value pairs each appended to the end of the URL, and separated by a "&" symbol. For large searches it begins to get difficult to write out by hand, and that is where `requests` comes in handy. Here we enter the additional arguments we want using a simple python dictionary into the entry 'params'. Below I show the URL for when we add the requirement that a record have coordinate data, and for when we add additional arguments to raise the limit for the number of records returned. The max records at a time (limit - offset) is 300. Above that you need to increment the offset to search higher values.

# %%
# add requirement that the record have coordinate data
res = requests.get(
    url=baseurl, 
    params={
        "q": "Bombus", 
        "hasCoordinate": "true",
    }
)
res.url
# Out:
# 'http://api.gbif.org/v1/occurrence/search?q=Bombus&hasCoordinate=true'

# %%
# request records 0-100
res = requests.get(
    url=baseurl, 
    params={
        "q": "Bombus", 
        "hasCoordinate": "true",
        "offset": "0", 
        "limit": "100"
    }
)
res.url
# Out:
# 'http://api.gbif.org/v1/occurrence/search?q=Bombus&hasCoordinate=true&offset=0&limit=100'

# %% [markdown]
# ### A complex search
# Here I request all Bombus records from 1900-1910 that are associated with a preserved speciment (as opposed to HUMAN_OBSERVATION or FOSSIL_SPECIMEN), has spatial data, and is in the US. The 'count' shows us that there are 4,977 records meeting these requirements. We requested the max of 300 records.

# %%
res = requests.get(
    url=baseurl, 
    params={
        "q": "Bombus", 
        "year": "1900,1910", 
        "basisOfRecord": "PRESERVED_SPECIMEN",
        "hasCoordinate": "true",
        "hasGeospatialIssue": "false",
        "country": "US",
        "offset": "0",
        "limit": "300"
    },
)
r2dict = res.json()
r2dict["count"]
# Out:
# 4977

# %%
res = requests.get(
    url=baseurl, 
    params={
        "q": "Bombus", 
        "year": "1900,1910", 
        "basisOfRecord": "PRESERVED_SPECIMEN",
        "hasCoordinate": "true",
        "hasGeospatialIssue": "false",
        "country": "US",
        "offset": "300",
        "limit": "300"
    },
)
r1dict = res.json()
r1dict["count"]
# Out:
# 4977

# %% [markdown]
# ### Combining many searches
# If we wanted to collect all records for a given search then we need to increment the "offset" argument until we reach the end of the records. Each is returned as a list of dictionaries, so we can just join all of those lists together and return them.

# %%
def get_all_records(searchparams):
    "iterate until end of records"
    start = 0
    data = []
    
    while 1:
        # make request and store results
        res = requests.get(
            url=baseurl, 
            params=searchparams,
        )
        # increment counter
        searchparams["offset"] = str(int(searchparams["offset"]) + 300)
        
        # concatenate data 
        idata = res.json()
        data += idata["results"]
        
        # stop when end of record is reached
        if idata["endOfRecords"]:
            break
        
    return data

# %%
data
# Out:
#                                            accessRights associatedReferences  \
# 0                                                   NaN                  NaN
# 1                                                   NaN                  NaN
# 2                                                   NaN                  NaN
# 3                                                   NaN                  NaN
# 4                                                   NaN                  NaN
# 5                                                   NaN                  NaN
# 6                                                   NaN                  NaN
# 7                                                   NaN                  NaN
# 8                                                   NaN                  NaN
# 9                                                   NaN                  NaN
# 10                                                  NaN                  NaN
# 11                                                  NaN                  NaN
# 12                                                  NaN                  NaN
# 13                                                  NaN                  NaN
# 14                                                  NaN                  NaN
# 15                                                  NaN                  NaN
# 16                                                  NaN                  NaN
# 17                                                  NaN                  NaN
# 18                                                  NaN                  NaN
# 19                                                  NaN                  NaN
# 20                                                  NaN                  NaN
# 21                                                  NaN                  NaN
# 22                                                  NaN                  NaN
# 23                                                  NaN                  NaN
# 24                                                  NaN                  NaN
# 25                                                  NaN                  NaN
# 26                                                  NaN                  NaN
# 27                                                  NaN                  NaN
# 28                                                  NaN                  NaN
# 29                                                  NaN                  NaN
# ...                                                 ...                  ...
# 1979  http://biodiversity.ku.edu/research/university...                  NaN
# 1980                                                NaN                  NaN
# 1981                                                NaN                  NaN
# 1982                                                NaN                  NaN
# 1983                                                NaN                  NaN
# 1984                                                NaN                  NaN
# 1985  http://biodiversity.ku.edu/research/university...                  NaN
# 1986  http://biodiversity.ku.edu/research/university...                  NaN
# 1987  http://biodiversity.ku.edu/research/university...                  NaN
# 1988                                                NaN                  NaN
# 1989  http://biodiversity.ku.edu/research/university...                  NaN
# 1990  http://biodiversity.ku.edu/research/university...                  NaN
# 1991                                                NaN                  NaN
# 1992                                                NaN                  NaN
# 1993                                                NaN                  NaN
# 1994                                                NaN                  NaN
# 1995                                                NaN                  NaN
# 1996                                                NaN                  NaN
# 1997                                                NaN                  NaN
# 1998                                                NaN                  NaN
# 1999                                                NaN                  NaN
# 2000                                                NaN                  NaN
# 2001                                                NaN                  NaN
# 2002                                                NaN                  NaN
# 2003                                                NaN                  NaN
# 2004                                                NaN                  NaN
# 2005                                                NaN                  NaN
# 2006                                                NaN                  NaN
# 2007                                                NaN                  NaN
# 2008                                                NaN                  NaN
#
#      associatedTaxa       basisOfRecord bibliographicCitation  \
# 0               NaN  PRESERVED_SPECIMEN                   NaN
# 1               NaN  PRESERVED_SPECIMEN                   NaN
# 2               NaN  PRESERVED_SPECIMEN                   NaN
# 3               NaN  PRESERVED_SPECIMEN                   NaN
# 4               NaN  PRESERVED_SPECIMEN                   NaN
# 5               NaN  PRESERVED_SPECIMEN                   NaN
# 6               NaN  PRESERVED_SPECIMEN                   NaN
# 7               NaN  PRESERVED_SPECIMEN                   NaN
# 8               NaN  PRESERVED_SPECIMEN                   NaN
# 9               NaN  PRESERVED_SPECIMEN                   NaN
# 10              NaN  PRESERVED_SPECIMEN                   NaN
# 11              NaN  PRESERVED_SPECIMEN                   NaN
# 12              NaN  PRESERVED_SPECIMEN                   NaN
# 13              NaN  PRESERVED_SPECIMEN                   NaN
# 14              NaN  PRESERVED_SPECIMEN                   NaN
# 15              NaN  PRESERVED_SPECIMEN                   NaN
# 16              NaN  PRESERVED_SPECIMEN                   NaN
# 17              NaN  PRESERVED_SPECIMEN                   NaN
# 18              NaN  PRESERVED_SPECIMEN                   NaN
# 19              NaN  PRESERVED_SPECIMEN                   NaN
# 20              NaN  PRESERVED_SPECIMEN                   NaN
# 21              NaN  PRESERVED_SPECIMEN                   NaN
# 22              NaN  PRESERVED_SPECIMEN                   NaN
# 23              NaN  PRESERVED_SPECIMEN                   NaN
# 24              NaN  PRESERVED_SPECIMEN                   NaN
# 25              NaN  PRESERVED_SPECIMEN                   NaN
# 26              NaN  PRESERVED_SPECIMEN                   NaN
# 27              NaN  PRESERVED_SPECIMEN                   NaN
# 28              NaN  PRESERVED_SPECIMEN                   NaN
# 29              NaN  PRESERVED_SPECIMEN                   NaN
# ...             ...                 ...                   ...
# 1979            NaN  PRESERVED_SPECIMEN                   NaN
# 1980            NaN  PRESERVED_SPECIMEN                   NaN
# 1981            NaN  PRESERVED_SPECIMEN                   NaN
# 1982            NaN  PRESERVED_SPECIMEN                   NaN
# 1983            NaN  PRESERVED_SPECIMEN                   NaN
# 1984            NaN  PRESERVED_SPECIMEN                   NaN
# 1985            NaN  PRESERVED_SPECIMEN                   NaN
# 1986            NaN  PRESERVED_SPECIMEN                   NaN
# 1987            NaN  PRESERVED_SPECIMEN                   NaN
# 1988            NaN  PRESERVED_SPECIMEN                   NaN
# 1989            NaN  PRESERVED_SPECIMEN                   NaN
# 1990            NaN  PRESERVED_SPECIMEN                   NaN
# 1991            NaN  PRESERVED_SPECIMEN                   NaN
# 1992            NaN  PRESERVED_SPECIMEN                   NaN
# 1993            NaN  PRESERVED_SPECIMEN                   NaN
# 1994            NaN  PRESERVED_SPECIMEN                   NaN
# 1995            NaN  PRESERVED_SPECIMEN                   NaN
# 1996            NaN  PRESERVED_SPECIMEN                   NaN
# 1997            NaN  PRESERVED_SPECIMEN                   NaN
# 1998            NaN  PRESERVED_SPECIMEN                   NaN
# 1999            NaN  PRESERVED_SPECIMEN                   NaN
# 2000            NaN  PRESERVED_SPECIMEN                   NaN
# 2001            NaN  PRESERVED_SPECIMEN                   NaN
# 2002            NaN  PRESERVED_SPECIMEN                   NaN
# 2003            NaN  PRESERVED_SPECIMEN                   NaN
# 2004            NaN  PRESERVED_SPECIMEN                   NaN
# 2005            NaN  PRESERVED_SPECIMEN                   NaN
# 2006            NaN  PRESERVED_SPECIMEN                   NaN
# 2007            NaN  PRESERVED_SPECIMEN                   NaN
# 2008            NaN  PRESERVED_SPECIMEN                   NaN
#
#                  catalogNumber    class  classKey     collectionCode  \
# 0     Insect Collection 248415  Insecta       216  Insect Collection
# 1     Insect Collection 241658  Insecta       216  Insect Collection
# 2     Insect Collection 247326  Insecta       216  Insect Collection
# 3     Insect Collection 247833  Insecta       216  Insect Collection
# 4     Insect Collection 248829  Insecta       216  Insect Collection
# 5     Insect Collection 233501  Insecta       216  Insect Collection
# 6     Insect Collection 241382  Insecta       216  Insect Collection
# 7     Insect Collection 247337  Insecta       216  Insect Collection
# 8     Insect Collection 247344  Insecta       216  Insect Collection
# 9     Insect Collection 247305  Insecta       216  Insect Collection
# 10    Insect Collection 250063  Insecta       216  Insect Collection
# 11    Insect Collection 252262  Insecta       216  Insect Collection
# 12    Insect Collection 332069  Insecta       216  Insect Collection
# 13                     BOMBUS6  Insecta       216               BBSL
# 14    Insect Collection 239674  Insecta       216  Insect Collection
# 15    Insect Collection 242492  Insecta       216  Insect Collection
# 16    Insect Collection 247332  Insecta       216  Insect Collection
# 17    Insect Collection 248673  Insecta       216  Insect Collection
# 18    Insect Collection 332041  Insecta       216  Insect Collection
# 19    Insect Collection 241503  Insecta       216  Insect Collection
# 20    Insect Collection 252249  Insecta       216  Insect Collection
# 21    Insect Collection 253479  Insecta       216  Insect Collection
# 22    Insect Collection 255961  Insecta       216  Insect Collection
# 23    Insect Collection 239431  Insecta       216  Insect Collection
# 24    Insect Collection 247336  Insecta       216  Insect Collection
# 25    Insect Collection 332083  Insecta       216  Insect Collection
# 26    Insect Collection 239049  Insecta       216  Insect Collection
# 27    Insect Collection 242652  Insecta       216  Insect Collection
# 28    Insect Collection 247310  Insecta       216  Insect Collection
# 29    Insect Collection 247317  Insecta       216  Insect Collection
# ...                        ...      ...       ...                ...
# 1979                    655409  Insecta       216               SEMC
# 1980            USNMENT1007572  Insecta       216         Entomology
# 1981            USNMENT1005916  Insecta       216         Entomology
# 1982            USNMENT1034872  Insecta       216         Entomology
# 1983            USNMENT1042463  Insecta       216         Entomology
# 1984               OSUC 121633  Insecta       216            Insects
# 1985                    655408  Insecta       216               SEMC
# 1986                    646082  Insecta       216               SEMC
# 1987                    655419  Insecta       216               SEMC
# 1988            USNMENT1040533  Insecta       216         Entomology
# 1989                    655441  Insecta       216               SEMC
# 1990                    651949  Insecta       216               SEMC
# 1991            USNMENT1002920  Insecta       216         Entomology
# 1992               OSUC 121759  Insecta       216            Insects
# 1993               OSUC 121632  Insecta       216            Insects
# 1994               OSUC 124119  Insecta       216            Insects
# 1995               OSUC 121760  Insecta       216            Insects
# 1996               OSUC 124141  Insecta       216            Insects
# 1997               OSUC 124047  Insecta       216            Insects
# 1998               OSUC 123962  Insecta       216            Insects
# 1999               OSUC 123963  Insecta       216            Insects
# 2000               OSUC 124120  Insecta       216            Insects
# 2001               OSUC 122522  Insecta       216            Insects
# 2002               OSUC 122926  Insecta       216            Insects
# 2003               OSUC 122521  Insecta       216            Insects
# 2004               OSUC 122923  Insecta       216            Insects
# 2005               OSUC 123328  Insecta       216            Insects
# 2006               OSUC 123243  Insecta       216            Insects
# 2007               OSUC 124043  Insecta       216            Insects
# 2008               OSUC 122242  Insecta       216            Insects
#
#      collectionID  ...  startDayOfYear  stateProvince  taxonKey   taxonRank  \
# 0             NaN  ...             NaN       Illinois   1340472     SPECIES
# 1             NaN  ...             NaN     Washington   1340324     SPECIES
# 2             NaN  ...             NaN       Illinois   1340472     SPECIES
# 3             NaN  ...             NaN     Washington   1340439     SPECIES
# 4             NaN  ...             NaN       Illinois   1340350     SPECIES
# 5             NaN  ...             NaN         Oregon   1340470     SPECIES
# 6             NaN  ...             NaN       Illinois   1340448     SPECIES
# 7             NaN  ...             NaN       Illinois   1340472     SPECIES
# 8             NaN  ...             NaN       Illinois   1340472     SPECIES
# 9             NaN  ...             NaN       Illinois   1340472     SPECIES
# 10            NaN  ...             NaN       Illinois   1340472     SPECIES
# 11            NaN  ...             NaN       Illinois   1340448     SPECIES
# 12            NaN  ...             NaN     New Jersey   1340409     SPECIES
# 13            NaN  ...             NaN       Illinois   1340350     SPECIES
# 14            NaN  ...             NaN        Montana   1340470     SPECIES
# 15            NaN  ...             NaN         Oregon   1340369     SPECIES
# 16            NaN  ...             NaN       Illinois   1340472     SPECIES
# 17            NaN  ...             NaN       Illinois   1340350     SPECIES
# 18            NaN  ...             NaN       Illinois   1340472     SPECIES
# 19            NaN  ...             NaN     Washington   1340324     SPECIES
# 20            NaN  ...             NaN       Illinois   1340448     SPECIES
# 21            NaN  ...             NaN        Montana   1340347     SPECIES
# 22            NaN  ...             NaN       New York   1340516     SPECIES
# 23            NaN  ...             NaN       Illinois   1340409     SPECIES
# 24            NaN  ...             NaN       Illinois   1340472     SPECIES
# 25            NaN  ...             NaN       Illinois   1340350     SPECIES
# 26            NaN  ...             NaN       Michigan   1340457     SPECIES
# 27            NaN  ...             NaN       Illinois   1340432     SPECIES
# 28            NaN  ...             NaN       Illinois   1340472     SPECIES
# 29            NaN  ...             NaN       Illinois   1340472     SPECIES
# ...           ...  ...             ...            ...       ...         ...
# 1979          NaN  ...             NaN        Arizona   1340475     SPECIES
# 1980          NaN  ...             208  New Hampshire   1340478     SPECIES
# 1981          NaN  ...             182     California   1340280     SPECIES
# 1982          NaN  ...             304        Georgia   1340416     SPECIES
# 1983          NaN  ...             263       Nebraska   1340448     SPECIES
# 1984          NaN  ...             NaN           Ohio   1340481     SPECIES
# 1985          NaN  ...             NaN        Arizona   1340475     SPECIES
# 1986          NaN  ...             NaN         Kansas   1340416     SPECIES
# 1987          NaN  ...             NaN        Arizona   1340475     SPECIES
# 1988          NaN  ...             222  New Hampshire   8947421  SUBSPECIES
# 1989          NaN  ...             NaN        Arizona   1340475     SPECIES
# 1990          NaN  ...             NaN        Arizona   1340347     SPECIES
# 1991          NaN  ...             208  New Hampshire   1340478     SPECIES
# 1992          NaN  ...             NaN           Ohio   1340382     SPECIES
# 1993          NaN  ...             NaN           Ohio   1340481     SPECIES
# 1994          NaN  ...             NaN         Kansas   1340448     SPECIES
# 1995          NaN  ...             NaN           Ohio   1340382     SPECIES
# 1996          NaN  ...             NaN           Ohio   1340416     SPECIES
# 1997          NaN  ...             NaN           Ohio   1340312     SPECIES
# 1998          NaN  ...             NaN           Utah   1340332     SPECIES
# 1999          NaN  ...             NaN           Utah   1340332     SPECIES
# 2000          NaN  ...             NaN         Kansas   1340449     SPECIES
# 2001          NaN  ...             NaN           Utah   4669895       GENUS
# 2002          NaN  ...             NaN           Utah   4669895       GENUS
# 2003          NaN  ...             NaN           Utah   4669895       GENUS
# 2004          NaN  ...             NaN           Utah   4669895       GENUS
# 2005          NaN  ...             NaN           Utah   4669895       GENUS
# 2006          NaN  ...             NaN         Oregon   4669895       GENUS
# 2007          NaN  ...             NaN           Ohio   1345418       GENUS
# 2008          NaN  ...             NaN           Utah   4669895       GENUS
#
#      taxonRemarks            type  typeStatus verbatimEventDate  \
# 0             NaN             NaN         NaN               NaN
# 1             NaN             NaN         NaN               NaN
# 2             NaN             NaN         NaN               NaN
# 3             NaN             NaN         NaN               NaN
# 4             NaN             NaN         NaN               NaN
# 5             NaN             NaN         NaN               NaN
# 6             NaN             NaN         NaN               NaN
# 7             NaN             NaN         NaN               NaN
# 8             NaN             NaN         NaN               NaN
# 9             NaN             NaN         NaN               NaN
# 10            NaN             NaN         NaN               NaN
# 11            NaN             NaN         NaN               NaN
# 12            NaN             NaN         NaN               NaN
# 13            NaN             NaN         NaN               NaN
# 14            NaN             NaN         NaN               NaN
# 15            NaN             NaN         NaN               NaN
# 16            NaN             NaN         NaN               NaN
# 17            NaN             NaN         NaN               NaN
# 18            NaN             NaN         NaN               NaN
# 19            NaN             NaN         NaN               NaN
# 20            NaN             NaN         NaN               NaN
# 21            NaN             NaN         NaN               NaN
# 22            NaN             NaN         NaN               NaN
# 23            NaN             NaN         NaN               NaN
# 24            NaN             NaN         NaN               NaN
# 25            NaN             NaN         NaN               NaN
# 26            NaN             NaN         NaN               NaN
# 27            NaN             NaN         NaN               NaN
# 28            NaN             NaN         NaN               NaN
# 29            NaN             NaN         NaN               NaN
# ...           ...             ...         ...               ...
# 1979          NaN             NaN         NaN               NaN
# 1980          NaN  PhysicalObject         NaN      July 26 1904
# 1981          NaN  PhysicalObject         NaN             VII.5
# 1982          NaN  PhysicalObject         NaN          Oct 1902
# 1983          NaN  PhysicalObject         NaN          IX 20-03
# 1984          NaN             NaN         NaN  2 September 1902
# 1985          NaN             NaN         NaN               NaN
# 1986          NaN             NaN         NaN               NaN
# 1987          NaN             NaN         NaN               NaN
# 1988          NaN  PhysicalObject         NaN        Aug 9 1904
# 1989          NaN             NaN         NaN               NaN
# 1990          NaN             NaN         NaN               NaN
# 1991          NaN  PhysicalObject         NaN      July 26 1904
# 1992          NaN             NaN         NaN       2 July 1902
# 1993          NaN             NaN         NaN      27 June 1902
# 1994          NaN             NaN         NaN    5 October 1900
# 1995          NaN             NaN         NaN      27 June 1902
# 1996          NaN             NaN         NaN    8 October 1904
# 1997          NaN             NaN         NaN      27 June 1902
# 1998          NaN             NaN         NaN       3 July 1904
# 1999          NaN             NaN         NaN      30 July 1904
# 2000          NaN             NaN         NaN    5 October 1900
# 2001          NaN             NaN         NaN  2 September 1903
# 2002          NaN             NaN         NaN     23 April 1905
# 2003          NaN             NaN         NaN      25 July 1903
# 2004          NaN             NaN         NaN        8 May 1903
# 2005          NaN             NaN         NaN    11 August 1903
# 2006          NaN             NaN         NaN      12 July 1905
# 2007          NaN             NaN         NaN       7 July 1904
# 2008          NaN             NaN         NaN     4 August 1904
#
#      vernacularName  year
# 0               NaN  1905
# 1               NaN  1902
# 2               NaN  1905
# 3               NaN  1905
# 4               NaN  1905
# 5               NaN  1905
# 6               NaN  1900
# 7               NaN  1905
# 8               NaN  1905
# 9               NaN  1905
# 10              NaN  1903
# 11              NaN  1902
# 12              NaN  1901
# 13              NaN  1904
# 14              NaN  1904
# 15              NaN  1900
# 16              NaN  1905
# 17              NaN  1901
# 18              NaN  1905
# 19              NaN  1901
# 20              NaN  1905
# 21              NaN  1902
# 22              NaN  1904
# 23              NaN  1903
# 24              NaN  1905
# 25              NaN  1905
# 26              NaN  1903
# 27              NaN  1905
# 28              NaN  1905
# 29              NaN  1905
# ...             ...   ...
# 1979            NaN  1902
# 1980            NaN  1904
# 1981            NaN  1905
# 1982            NaN  1902
# 1983            NaN  1903
# 1984            NaN  1902
# 1985            NaN  1902
# 1986            NaN  1903
# 1987            NaN  1902
# 1988            NaN  1904
# 1989            NaN  1902
# 1990            NaN  1902
# 1991            NaN  1904
# 1992            NaN  1902
# 1993            NaN  1902
# 1994            NaN  1900
# 1995            NaN  1902
# 1996            NaN  1904
# 1997            NaN  1902
# 1998            NaN  1904
# 1999            NaN  1904
# 2000            NaN  1900
# 2001            NaN  1903
# 2002            NaN  1905
# 2003            NaN  1903
# 2004            NaN  1903
# 2005            NaN  1903
# 2006            NaN  1905
# 2007            NaN  1904
# 2008            NaN  1904
#
# [2009 rows x 103 columns]

# %%
df = pd.DataFrame(data)
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# make params dictionary
searchparams = {
    "q": "Bombus", 
    "year": "1900,1905", 
    "basisOfRecord": "PRESERVED_SPECIMEN",
    "hasCoordinate": "true",
    "hasGeospatialIssue": "false",
    "country": "US",
    "offset": "0",
    "limit": "300"
}

# call function to search over all offset values until end
data = get_all_records(searchparams)

# %% [markdown]
# ### The full data

# %%
# convert to a data frame
df = pd.DataFrame(data)
df.shape
# Out:
# (2009, 103)

# %%
# keys (columns) in the dataframe (there are many!)
list(df.columns)
# Out:
# ['accessRights',
#  'associatedReferences',
#  'associatedTaxa',
#  'basisOfRecord',
#  'bibliographicCitation',
#  'catalogNumber',
#  'class',
#  'classKey',
#  'collectionCode',
#  'collectionID',
#  'continent',
#  'coordinatePrecision',
#  'coordinateUncertaintyInMeters',
#  'country',
#  'countryCode',
#  'county',
#  'crawlId',
#  'datasetID',
#  'datasetKey',
#  'datasetName',
#  'dateIdentified',
#  'day',
#  'decimalLatitude',
#  'decimalLongitude',
#  'dynamicProperties',
#  'elevation',
#  'elevationAccuracy',
#  'endDayOfYear',
#  'eventDate',
#  'eventRemarks',
#  'extensions',
#  'facts',
#  'family',
#  'familyKey',
#  'fieldNotes',
#  'gbifID',
#  'genericName',
#  'genus',
#  'genusKey',
#  'geodeticDatum',
#  'georeferenceProtocol',
#  'georeferenceRemarks',
#  'georeferenceSources',
#  'georeferencedBy',
#  'higherClassification',
#  'higherGeography',
#  'identifiedBy',
#  'identifier',
#  'identifiers',
#  'individualCount',
#  'infraspecificEpithet',
#  'institutionCode',
#  'institutionID',
#  'issues',
#  'key',
#  'kingdom',
#  'kingdomKey',
#  'language',
#  'lastCrawled',
#  'lastInterpreted',
#  'lastParsed',
#  'license',
#  'lifeStage',
#  'locality',
#  'media',
#  'modified',
#  'month',
#  'nomenclaturalCode',
#  'occurrenceID',
#  'occurrenceRemarks',
#  'order',
#  'orderKey',
#  'organismID',
#  'ownerInstitutionCode',
#  'phylum',
#  'phylumKey',
#  'preparations',
#  'previousIdentifications',
#  'protocol',
#  'publishingCountry',
#  'publishingOrgKey',
#  'recordedBy',
#  'references',
#  'relations',
#  'rightsHolder',
#  'samplingProtocol',
#  'scientificName',
#  'scientificNameID',
#  'sex',
#  'source',
#  'species',
#  'speciesKey',
#  'specificEpithet',
#  'startDayOfYear',
#  'stateProvince',
#  'taxonKey',
#  'taxonRank',
#  'taxonRemarks',
#  'type',
#  'typeStatus',
#  'verbatimEventDate',
#  'vernacularName',
#  'year']

# %%
# view just the columns we're interested in for now.
sdf = df[["species", "year", "decimalLatitude", "decimalLongitude"]]
sdf.head()
# Out:
#              species  year  decimalLatitude  decimalLongitude
# 0      Bombus vagans  1905         42.09606         -90.16255
# 1   Bombus centralis  1902         47.94167        -119.00222
# 2      Bombus vagans  1905         42.09606         -90.16255
# 3  Bombus nevadensis  1905         46.73139        -117.17861
# 4   Bombus impatiens  1905         41.86750         -90.15940

# %%
# how many records?
sdf.shape
# Out:
# (2009, 4)

# %%
# which unique species?
sdf.species.unique()
# Out:
# array(['Bombus vagans', 'Bombus centralis', 'Bombus nevadensis',
#        'Bombus impatiens', 'Bombus appositus', 'Bombus variabilis',
#        'Bombus griseocollis', 'Bombus huntii', 'Bombus rufocinctus',
#        'Bombus ternarius', 'Bombus ashtoni', 'Bombus fraternus',
#        'Bombus pensylvanicus', 'Bombus bifarius', 'Bombus affinis',
#        'Bombus borealis', 'Bombus morrisoni', 'Bombus citrinus',
#        'Bombus terricola', 'Bombus perplexus', 'Bombus fernaldae',
#        'Bombus melanopygus', 'Bombus sylvicola', 'Bombus fervidus',
#        'Bombus auricomus', 'Bombus sandersoni', 'Bombus mixtus',
#        'Bombus vosnesenskii', 'Bombus crotchii', 'Bombus insularis',
#        'Bombus bimaculatus', 'Bombus occidentalis', 'Bombus cockerelli',
#        nan, 'Bombus balteatus', 'Bombus lapponicus',
#        'Bombus californicus', 'Bombus suckleyi', 'Bombus patagiatus',
#        'Bombus flavifrons', 'Bombus sitkensis', 'Bombus neoboreus',
#        'Bombus rufosuffusus', 'Bombus separatus'], dtype=object)

# %%
# exclude nan and count species
mask = sdf.species.notna()
df.species[mask].unique().size
# Out:
# 43

# %%
# plot the number of each species in order
sp_counts = df.species[mask].value_counts()
toyplot.bars(sp_counts, height=350, title=sp_counts.index);
# Out:
# <div class="toyplot" id="t21f70c1191dc49f9ae27d44550db0a55" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="350.0px" id="t1bf622767a3444d8b86cd7e8e7916db5" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 350.0" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t15771b583bd34386893755dcf770983d"><clipPath id="t45aceebaa7fd410393b29b1ee42d0abd"><rect height="270.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t45aceebaa7fd410393b29b1ee42d0abd)"><g class="toyplot-mark-BarMagnitudes" id="t7e6d81a2588242289a9697f0bdd97663" style="stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><g class="toyplot-Series"><rect class="toyplot-Datum" height="250.0" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="11.627906976744178" x="50.0" y="50.0"><title>Bombus impatiens</title></rect><rect class="toyplot-Datum" height="217.34234234234236" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="11.627906976744192" x="61.62790697674418" y="82.65765765765765"><title>Bombus vagans</title></rect><rect class="toyplot-Datum" height="181.3063063063063" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="11.627906976744185" x="73.25581395348837" y="118.69369369369369"><title>Bombus occidentalis</title></rect><rect class="toyplot-Datum" height="171.17117117117118" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="11.627906976744185" x="84.88372093023256" y="128.82882882882882"><title>Bombus pensylvanicus</title></rect><rect class="toyplot-Datum" height="162.1621621621622" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="11.627906976744185" x="96.51162790697674" y="137.8378378378378"><title>Bombus fervidus</title></rect><rect class="toyplot-Datum" height="110.36036036036035" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="11.627906976744185" x="108.13953488372093" y="189.63963963963965"><title>Bombus affinis</title></rect><rect class="toyplot-Datum" height="106.98198198198199" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="11.627906976744185" x="119.76744186046511" y="193.018018018018"><title>Bombus griseocollis</title></rect><rect class="toyplot-Datum" height="104.72972972972971" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="11.627906976744185" x="131.3953488372093" y="195.2702702702703"><title>Bombus terricola</title></rect><rect class="toyplot-Datum" height="94.59459459459458" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="11.627906976744185" x="143.02325581395348" y="205.40540540540542"><title>Bombus centralis</title></rect><rect class="toyplot-Datum" height="82.2072072072072" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="11.627906976744185" x="154.65116279069767" y="217.7927927927928"><title>Bombus morrisoni</title></rect><rect class="toyplot-Datum" height="76.57657657657657" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;strok ...

# %% [markdown]
# ## Assignment:

# %% [markdown]
# ### Task 1:
# Write a Class object called `Records` that can be given a taxon name query and a range of years and will return a class instance with all results from GBIF for the queried range using the same params from our example above, except allowing the 'q' and 'year' arguments to vary. You can reuse the code above to create the core functions for your object. When finished, you should be able to use the object in the following way. This means that after writing your Class object, test it using the code below and make sure it gives proper results.

# %%
# fill in the params dictionary, write functions to update it
# with the entered arguments to __init__, write functions
# to get_all_records and store results as a dataframe.
# have all functions run during init so that the initialized
# object calls the request and returns a full dataframe. 

class Record:
    def __init__(self, q=None, interval=None):
        
        self.q = q
        self.interval = interval
        self.params = {}
        self.df = self._get_all_records()
    
    def _get_all_records(self):
        "Iterates until the end of records and returns the data"
        start = 0
        data = []
        self.params = {
        "q": self.q, 
        "year": self.interval, 
        "basisOfRecord": "PRESERVED_SPECIMEN",
        "hasCoordinate": "true",
        "hasGeospatialIssue": "false",
        "country": "US",
        "offset": "0",
        "limit": "300",
        }
        while 1:
            # make requests and store results
            res = requests.get(
                url = "http://api.gbif.org/v1/occurrence/search?",
                params = self.params,            
            )
            # increment counter
            self.params["offset"] = str(int(self.params["offset"]) + 300)
        
            # concatenate data 
            idata = res.json()
            data += idata["results"]
        
            # stop when end of record is reached
            if idata["endOfRecords"]:
                break
       
        return pd.DataFrame(data)

# %%
rec = Record("Bombus", "1950,1955")

# %%
rec.df
# Out:
#                                            accessRights associatedReferences  \
# 0                                                   NaN                  NaN
# 1                                                   NaN                  NaN
# 2                                                   NaN                  NaN
# 3                                                   NaN                  NaN
# 4                                                   NaN                  NaN
# 5                                                   NaN                  NaN
# 6                                                   NaN                  NaN
# 7                                                   NaN                  NaN
# 8                                                   NaN                  NaN
# 9                                                   NaN                  NaN
# 10                                                  NaN                  NaN
# 11                                                  NaN                  NaN
# 12                                                  NaN                  NaN
# 13                                                  NaN                  NaN
# 14                                                  NaN                  NaN
# 15                                                  NaN                  NaN
# 16                                                  NaN                  NaN
# 17                                                  NaN                  NaN
# 18                                                  NaN                  NaN
# 19                                                  NaN                  NaN
# 20                                                  NaN                  NaN
# 21                                                  NaN                  NaN
# 22                                                  NaN                  NaN
# 23                                                  NaN                  NaN
# 24                                                  NaN                  NaN
# 25                                                  NaN                  NaN
# 26                                                  NaN                  NaN
# 27                                                  NaN                  NaN
# 28                                                  NaN                  NaN
# 29                                                  NaN                  NaN
# ...                                                 ...                  ...
# 6924                                                NaN                  NaN
# 6925                                                NaN                  NaN
# 6926                                                NaN                  NaN
# 6927                                                NaN                  NaN
# 6928                                                NaN                  NaN
# 6929                                                NaN                  NaN
# 6930                                                NaN                  NaN
# 6931                                                NaN                  NaN
# 6932                                                NaN                  NaN
# 6933                                                NaN                  NaN
# 6934                                                NaN                  NaN
# 6935                                                NaN                  NaN
# 6936                                                NaN                  NaN
# 6937                                                NaN                  NaN
# 6938                                                NaN                  NaN
# 6939                                                NaN                  NaN
# 6940                                                NaN                  NaN
# 6941                                                NaN                  NaN
# 6942                                                NaN                  NaN
# 6943                                                NaN                  NaN
# 6944                                                NaN                  NaN
# 6945                                                NaN                  NaN
# 6946                                                NaN                  NaN
# 6947  https://www.fieldmuseum.org/about/copyright-in...                  NaN
# 6948                                                NaN                  NaN
# 6949                                                NaN                  NaN
# 6950                                                NaN                  NaN
# 6951                                                NaN                  NaN
# 6952                                                NaN                  NaN
# 6953                                                NaN                  NaN
#
#      associatedTaxa       basisOfRecord behavior bibliographicCitation  \
# 0               NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 1               NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 2               NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 3               NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 4               NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 5               NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6               NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 7               NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 8               NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 9               NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 10              NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 11              NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 12              NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 13              NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 14              NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 15              NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 16              NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 17              NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 18              NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 19              NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 20              NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 21              NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 22              NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 23              NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 24              NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 25              NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 26              NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 27              NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 28              NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 29              NaN  PRESERVED_SPECIMEN      NaN                   NaN
# ...             ...                 ...      ...                   ...
# 6924            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6925            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6926            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6927            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6928            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6929            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6930            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6931            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6932            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6933            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6934            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6935            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6936            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6937            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6938            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6939            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6940            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6941            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6942            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6943            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6944            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6945            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6946            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6947            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6948            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6949            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6950            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6951            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6952            NaN  PRESERVED_SPECIMEN      NaN                   NaN
# 6953            NaN  PRESERVED_SPECIMEN      NaN                   NaN
#
#                  catalogNumber    class  classKey     collectionCode  ...   \
# 0                      BOMBUS5  Insecta       216               BBSL  ...
# 1     Insect Collection 255802  Insecta       216  Insect Collection  ...
# 2     Insect Collection 334996  Insecta       216  Insect Collection  ...
# 3      Insect Collection 67614  Insecta       216  Insect Collection  ...
# 4     Insect Collection 253774  Insecta       216  Insect Collection  ...
# 5     Insect Collection 253174  Insecta       216  Insect Collection  ...
# 6     Insect Collection 253250  Insecta       216  Insect Collection  ...
# 7     Insect Collection 248416  Insecta       216  Insect Collection  ...
# 8     Insect Collection 256544  Insecta       216  Insect Collection  ...
# 9     Insect Collection 257146  Insecta       216  Insect Collection  ...
# 10    Insect Collection 257242  Insecta       216  Insect Collection  ...
# 11    Insect Collection 253775  Insecta       216  Insect Collection  ...
# 12    Insect Collection 257247  Insecta       216  Insect Collection  ...
# 13    Insect Collection 334985  Insecta       216  Insect Collection  ...
# 14    Insect Collection 293465  Insecta       216  Insect Collection  ...
# 15    Insect Collection 257250  Insecta       216  Insect Collection  ...
# 16    Insect Collection 253782  Insecta       216  Insect Collection  ...
# 17    Insect Collection 257248  Insecta       216  Insect Collection  ...
# 18    Insect Collection 253783  Insecta       216  Insect Collection  ...
# 19    Insect Collection 243929  Insecta       216  Insect Collection  ...
# 20    Insect Collection 256534  Insecta       216  Insect Collection  ...
# 21    Insect Collection 253785  Insecta       216  Insect Collection  ...
# 22    Insect Collection 253790  Insecta       216  Insect Collection  ...
# 23    Insect Collection 334995  Insecta       216  Insect Collection  ...
# 24    Insect Collection 253793  Insecta       216  Insect Collection  ...
# 25    Insect Collection 332078  Insecta       216  Insect Collection  ...
# 26    Insect Collection 244402  Insecta       216  Insect Collection  ...
# 27    Insect Collection 245957  Insecta       216  Insect Collection  ...
# 28    Insect Collection 334924  Insecta       216  Insect Collection  ...
# 29    Insect Collection 253787  Insecta       216  Insect Collection  ...
# ...                        ...      ...       ...                ...  ...
# 6924                    146980  Insecta       216   Insect specimens  ...
# 6925                    122516  Insecta       216   Insect specimens  ...
# 6926                    155274  Insecta       216   Insect specimens  ...
# 6927                    155281  Insecta       216   Insect specimens  ...
# 6928                    120938  Insecta       216   Insect specimens  ...
# 6929                    155272  Insecta       216   Insect specimens  ...
# 6930                    147034  Insecta       216   Insect specimens  ...
# 6931                    122518  Insecta       216   Insect specimens  ...
# 6932                    146969  Insecta       216   Insect specimens  ...
# 6933                    155273  Insecta       216   Insect specimens  ...
# 6934                    146981  Insecta       216   Insect specimens  ...
# 6935                    146974  Insecta       216   Insect specimens  ...
# 6936                    146975  Insecta       216   Insect specimens  ...
# 6937                    146971  Insecta       216   Insect specimens  ...
# 6938                    146965  Insecta       216   Insect specimens  ...
# 6939                    146964  Insecta       216   Insect specimens  ...
# 6940                    146978  Insecta       216   Insect specimens  ...
# 6941                    146973  Insecta       216   Insect specimens  ...
# 6942                    146967  Insecta       216   Insect specimens  ...
# 6943                    155277  Insecta       216   Insect specimens  ...
# 6944                    155322  Insecta       216   Insect specimens  ...
# 6945               OSUC 119758  Insecta       216            Insects  ...
# 6946               OSUC 588345  Insecta       216            Insects  ...
# 6947      FMNHINS 0003 133 392  Insecta       216            Insects  ...
# 6948               OSUC 101081  Insecta       216            Insects  ...
# 6949               OSUC 101565  Insecta       216            Insects  ...
# 6950               OSUC 101566  Insecta       216            Insects  ...
# 6951               OSUC 101106  Insecta       216            Insects  ...
# 6952               OSUC 510953  Insecta       216            Insects  ...
# 6953                    147041  Insecta       216   Insect specimens  ...
#
#      taxonKey taxonRank  taxonRemarks            type  \
# 0     1340350   SPECIES           NaN             NaN
# 1     1340516   SPECIES           NaN             NaN
# 2     1340448   SPECIES           NaN             NaN
# 3     1340493   SPECIES           NaN             NaN
# 4     1340416   SPECIES           NaN             NaN
# 5     1340350   SPECIES           NaN             NaN
# 6     1340350   SPECIES           NaN             NaN
# 7     1340472   SPECIES           NaN             NaN
# 8     1340493   SPECIES           NaN             NaN
# 9     1340478   SPECIES           NaN             NaN
# 10    1340350   SPECIES           NaN             NaN
# 11    1340446   SPECIES           NaN             NaN
# 12    1340416   SPECIES           NaN             NaN
# 13    1340448   SPECIES           NaN             NaN
# 14    1340446   SPECIES           NaN             NaN
# 15    1340350   SPECIES           NaN             NaN
# 16    1340472   SPECIES           NaN             NaN
# 17    1340416   SPECIES           NaN             NaN
# 18    1340350   SPECIES           NaN             NaN
# 19    1340350   SPECIES           NaN             NaN
# 20    1340493   SPECIES           NaN             NaN
# 21    1340350   SPECIES           NaN             NaN
# 22    1340409   SPECIES           NaN             NaN
# 23    1340448   SPECIES           NaN             NaN
# 24    1340416   SPECIES           NaN             NaN
# 25    1340350   SPECIES           NaN             NaN
# 26    1340409   SPECIES           NaN             NaN
# 27    1340416   SPECIES           NaN             NaN
# 28    1340312   SPECIES           NaN             NaN
# 29    1340409   SPECIES           NaN             NaN
# ...       ...       ...           ...             ...
# 6924  1340467   SPECIES           NaN  PhysicalObject
# 6925  1340467   SPECIES           NaN  PhysicalObject
# 6926  1340467   SPECIES           NaN  PhysicalObject
# 6927  1340467   SPECIES           NaN  PhysicalObject
# 6928  1340467   SPECIES           NaN  PhysicalObject
# 6929  1340467   SPECIES           NaN  PhysicalObject
# 6930  1340484   SPECIES           NaN  PhysicalObject
# 6931  1340467   SPECIES           NaN  PhysicalObject
# 6932  1340467   SPECIES           NaN  PhysicalObject
# 6933  1340467   SPECIES           NaN  PhysicalObject
# 6934  1340467   SPECIES           NaN  PhysicalObject
# 6935  1340467   SPECIES           NaN  PhysicalObject
# 6936  1340467   SPECIES           NaN  PhysicalObject
# 6937  1340467   SPECIES           NaN  PhysicalObject
# 6938  1340467   SPECIES           NaN  PhysicalObject
# 6939  1340467   SPECIES           NaN  PhysicalObject
# 6940  1340467   SPECIES           NaN  PhysicalObject
# 6941  1340467   SPECIES           NaN  PhysicalObject
# 6942  1340467   SPECIES           NaN  PhysicalObject
# 6943  1340467   SPECIES           NaN  PhysicalObject
# 6944  1340328   SPECIES           NaN  PhysicalObject
# 6945  1340278     GENUS           NaN             NaN
# 6946  1340278     GENUS           NaN             NaN
# 6947  1340278     GENUS           NaN  PhysicalObject
# 6948  1340278     GENUS           NaN             NaN
# 6949  1340278     GENUS           NaN             NaN
# 6950  1340278     GENUS           NaN             NaN
# 6951  1340278     GENUS           NaN             NaN
# 6952  1340278     GENUS           NaN             NaN
# 6953  1340308   SPECIES           NaN  PhysicalObject
#
#      verbatimCoordinateSystem verbatimElevation  verbatimEventDate  \
# 0                         NaN               NaN                NaN
# 1                         NaN               NaN                NaN
# 2                         NaN               NaN                NaN
# 3                         NaN               NaN                NaN
# 4                         NaN               NaN                NaN
# 5                         NaN               NaN                NaN
# 6                         NaN               NaN                NaN
# 7                         NaN               NaN                NaN
# 8                         NaN               NaN                NaN
# 9                         NaN               NaN                NaN
# 10                        NaN               NaN                NaN
# 11                        NaN               NaN                NaN
# 12                        NaN               NaN                NaN
# 13                        NaN               NaN                NaN
# 14                        NaN               NaN                NaN
# 15                        NaN               NaN                NaN
# 16                        NaN               NaN                NaN
# 17                        NaN               NaN                NaN
# 18                        NaN               NaN                NaN
# 19                        NaN               NaN                NaN
# 20                        NaN               NaN                NaN
# 21                        NaN               NaN                NaN
# 22                        NaN               NaN                NaN
# 23                        NaN               NaN                NaN
# 24                        NaN               NaN                NaN
# 25                        NaN               NaN                NaN
# 26                        NaN               NaN                NaN
# 27                        NaN               NaN                NaN
# 28                        NaN               NaN                NaN
# 29                        NaN               NaN                NaN
# ...                       ...               ...                ...
# 6924          decimal degrees               NaN       16 June 1955
# 6925          decimal degrees               NaN        June 1 1953
# 6926          decimal degrees               NaN      Sept. 14 1950
# 6927          decimal degrees               NaN       July 18 1950
# 6928          decimal degrees               NaN       June 27 1951
# 6929          decimal degrees               NaN      Sept. 28 1950
# 6930          decimal degrees               NaN        20 Aug 1955
# 6931          decimal degrees               NaN        June 1 1953
# 6932          decimal degrees               NaN        19 vii 1953
# 6933          decimal degrees               NaN      Sept. 14 1950
# 6934          decimal degrees               NaN       16 June 1955
# 6935          decimal degrees               NaN        July 7 1953
# 6936          decimal degrees               NaN         7 Aug 1951
# 6937          decimal degrees               NaN        July 7 1953
# 6938          decimal degrees               NaN       July 30 1952
# 6939          decimal degrees               NaN       June 25 1953
# 6940          decimal degrees               NaN         7 Aug 1951
# 6941          decimal degrees               NaN        15 vii 1953
# 6942          decimal degrees               NaN        July 7 1953
# 6943          decimal degrees               NaN       July 20 1950
# 6944          decimal degrees               NaN        20 vii 1952
# 6945                      NaN               NaN       22 July 1950
# 6946                      NaN               NaN     20 August 1954
# 6947                      NaN               NaN                NaN
# 6948                      NaN               NaN     31 August 1955
# 6949                      NaN               NaN     31 August 1955
# 6950                      NaN               NaN     31 August 1955
# 6951                      NaN               NaN     29 August 1955
# 6952                      NaN               NaN       12 July 1953
# 6953          decimal degrees               NaN        Aug 17 1953
#
#                     verbatimLocality vernacularName  year
# 0                                NaN            NaN  1952
# 1                                NaN            NaN  1952
# 2                                NaN            NaN  1950
# 3                                NaN            NaN  1952
# 4                                NaN            NaN  1954
# 5                                NaN            NaN  1952
# 6                                NaN            NaN  1951
# 7                                NaN            NaN  1950
# 8                                NaN            NaN  1954
# 9                                NaN            NaN  1951
# 10                               NaN            NaN  1954
# 11                               NaN            NaN  1954
# 12                               NaN            NaN  1954
# 13                               NaN            NaN  1954
# 14                               NaN            NaN  1953
# 15                               NaN            NaN  1950
# 16                               NaN            NaN  1950
# 17                               NaN            NaN  1954
# 18                               NaN            NaN  1950
# 19                               NaN            NaN  1954
# 20                               NaN            NaN  1954
# 21                               NaN            NaN  1950
# 22                               NaN            NaN  1950
# 23                               NaN            NaN  1950
# 24                               NaN            NaN  1950
# 25                               NaN            NaN  1952
# 26                               NaN            NaN  1953
# 27                               NaN            NaN  1953
# 28                               NaN            NaN  1954
# 29                               NaN            NaN  1950
# ...                              ...            ...   ...
# 6924                         Eklutna            NaN  1955
# 6925  Palmer [USDA Research Station]            NaN  1953
# 6926  Palmer [USDA Research Station]            NaN  1950
# 6927                       Big Delta            NaN  1950
# 6928  Palmer [USDA Research Station]            NaN  1951
# 6929  Palmer [USDA Research Station]            NaN  1950
# 6930                       Ketchikan            NaN  1955
# 6931  Palmer [USDA Research Station]            NaN  1953
# 6932                   Lower Tonsina            NaN  1953
# 6933  Palmer [USDA Research Station]            NaN  1950
# 6934                    Anchor Point            NaN  1955
# 6935  Palmer [USDA Research Station]            NaN  1953
# 6936                           Homer            NaN  1951
# 6937  Palmer [USDA Research Station]            NaN  1953
# 6938                           Homer            NaN  1952
# 6939                           Homer            NaN  1953
# 6940                           Homer            NaN  1951
# 6941                         Chitina            NaN  1953
# 6942  Palmer [USDA Research Station]            NaN  1953
# 6943             College [Fairbanks]            NaN  1950
# 6944                     Eagle River            NaN  1952
# 6945                             NaN            NaN  1950
# 6946                             NaN            NaN  1954
# 6947                             NaN            NaN  1950
# 6948                             NaN            NaN  1955
# 6949                             NaN            NaN  1955
# 6950                             NaN            NaN  1955
# 6951                             NaN            NaN  1955
# 6952                             NaN            NaN  1953
# 6953                       Fairbanks            NaN  1953
#
# [6954 rows x 121 columns]

# %%
## access all of the returned records as a dataframe 
## (here asking for the shape to see how many records there are)
rec.df.shape
# Out:
# (6954, 121)

# %% [markdown]
# ### Task 2:
# Once you have tested your Record class object in this notebook and it is working, copy it to a new `.py` file in a text editor and name it records.py, and put this in a new folder called `records/`. Then add an `__init__.py` file and a `setup.py` file and structure this directory so that it can be imported as a Python package. If you need a review on how to do this look back at lecture 5, and the assignment from that lecture (https://github.com/programming-for-bio/5-Packaging/blob/master/Notebooks/nb-5.2-packaging.ipynb). This will be very similar to the 'helloworld' package that we wrote. When you are finished, install the package with pip and try importing it like below. Then push the `records` folder as a new repo to your GitHub account named records.

# %%
# import your library and access the Records class object from it
import record
rec = record.Record("Bombus",(1990, 2000))

# %%
rec

# %% [markdown]
# ### Task 3:
# I will post a working example on Friday so that you can *update or fix your code before the next class to ensure your code is working*. Then push your updated/fixed code to GitHub before the next class. You should hopefully be able to get it working, since you've done all of these tasks before. We are going to continue adding new functions to this library over the next two weeks, so if you get stuck on this assignment ask for help and try to keep up, because it will be very difficult if you get behind.
