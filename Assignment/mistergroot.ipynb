# %% [markdown]
# # Notebook 8.1 RESTful GBIF
#
# This notebook will introduce you to methods for parsing data from the web by accessing websites that have RESTful APIs. In the next notebook we will continue to other methods for parsing data from the web as well.
#
# These notebook will involve two core aspects: (1) Working with RESTful APIs, which we discussed briefly in lecture; and (2) Parsing HTML text. The first is much easier since the data that we query from the web is returned in a form that is easy to interpret and *meant* to be parsed and analyzed, whereas the second way requires us to learn a little about how the internet works, which is also useful stuff to know. So let's get started. You'll need to install the two libraries below.

# %%
# conda install beautifulsoup4
# conda install requests

# %%
import toyplot
import requests
import pandas as pd

# %% [markdown]
# ### The design of REST APIs.
# The idea behind REST APIs is that data on a server (like a webpage) can be accessed with a consistent type of argument in the form of a URL, to query data which will then be returned in a form that is easy to analyze (usually json or xml), as opposed to being returned in messy HTML that needs to be parsed. Many websites have REST APIs, but some are much easier to use than others.

# %% [markdown]
# ### Limits
# Many REST APIs have limits on the way that you can use them. For example, the REST APIs for Twitter, GitHub, and Reddit require that you login in order to access data, and some sites will throttle how many requests you can make per hour. Although usually sites with a REST API are intended to be searched, the tools we will learn here can be used to search almost any website. It is important to know that some sites will intentionally block you if you try too aggressively to scrape data from them. For example, google scholar and genbank both have limits on the number of queries you can make per hour.

# %% [markdown]
# ### Good REST APIs
# A good REST API will have good directions for its usage. Two very good examples are the [USDA Bison API](https://bison.usgs.gov/#api) and the [Global Biodiversity Information Facility (GBIF) API](https://www.gbif.org/developer/summary). We'll focus on the latter in this notebook. The GBIF database is an international effort to collect all observation data on plants, animals, and fungi into a single place where it can be searched. It is actually a conglomeration of many separate databases, with data from museums and similar institutions all over the world. These APIs are free to use but request that you cite them if the data is used in a publication eventually.

# %% [markdown]
# ### What does GBIF do?
# GBIF can be used to find specimen collection records, or other types of observation data, stored in museum type databases. The website offers a convenient way to request taxa by name, and to select specific research criteria. For example, if we wanted to find all specimens of bumblebees (genus *Bombus*) that were collected between 1910 and 1920 we could request this through the website. It will draw a nice map with their locations and you can download a table with coordinates of where they were collected. This is actually one of the best databases around, since it organizes the data quite easily for you to download, but nevertheless, we'll use it as our example to learn REST APIs.
#
# Even though GBIF has a very nice web interface, it is obviously often more efficient to be able to query this database programmatically, instead of having to type each name we wish to search, and click on several buttons. This can provide a much more powerful way of applying filters over many different types of searches. That is the idea behind REST APIs and the reason why GBIF provides one.

# %% [markdown]
# ### The base-url
# The base URL is the web address of the API. This is simply a string that we wil add arguments to in order to request particular types of data be returned to use from the database. For GBIF this is the following, which we'll store as a string for now. This base-url address is given to us right at the top of the [GBIF API documentation](https://www.gbif.org/developer/occurrence). You can see that it looks much like any other web address.

# %%
baseurl = "http://api.gbif.org/v1/occurrence/search?"

# %% [markdown]
# ### How to query GBIF
# As you can see in the URL below, an API query just has additional arguments added to the baseurl. The string below searches for records with the name *Bombus*, which is the genus for bumblebees. We've added just the 'query' option 'q' and the name. We'll see next how to make more complex queries. But first, copy the URL below (without the quotation marks around it) and paste it into a web browser. This will show you what the returned data looks like. It might look a bit different depending on which browser you are using (I recommend using firefox or chrome) but the underlying data is the same, and is called JSON data.

# %%
search_url = "http://api.gbif.org/v1/occurrence/search?q=Bombus"

# %% [markdown]
# ### JSON format
# We will be using the `requests` library to get data from online, but before we do, let's talk a bit about how the data will be structured so we know what to expect. The data that you should see in your browser now is called JSON formatted data.  You'll notice that this format is almost identical to what a Python dictionary looks like. It is composed of key:value pairs. This will make it particularly easy to work with.

# %% [markdown]
# ### Requests
#
# [Documentation](http://docs.python-requests.org/en/master/user/quickstart/)
#
# The `requests` package work a lot like an automated web browser. We've used `requests` briefly in the past but now we'll start to use it more effectively. The main function we will call is `.get()`, which will send a GET command to the web address and return a Response Class object. We will then access attributes and functions of the Response instance to see if our request worked, and to parse the resulting text from it. Let's try this on our `search_url` string defined above.

# %%
# create a Response instance from a request
response = requests.get(search_url)

# %%
# check that your request worked (200 = worked; other codes No))
response.status_code
# Out:
# 200

# %%
# this would return the error message if it didn't work (else None)
response.raise_for_status()

# %% [markdown]
# ### Parse a Response
# Before when we've used `requests` we've parsed the results as plain text, since it was usually in a format that was easiest to work with as a string. In this case, we are going to access the data a bit differently, by instead  accessing it in JSON format. This is easily available from the object just like text is. The first is not very easily readable or parseable, whereas the second can be accessed and searched more easily.

# %%
# first 500 characters of the .text string
response.text[:500]
# Out:
# '{"offset":0,"limit":20,"endOfRecords":false,"count":1048304,"results":[{"key":131330107,"datasetKey":"86aba78e-f762-11e1-a439-00145eb45e9a","publishingOrgKey":"8595cd50-87c0-11dc-bb35-b8a03c50a862","publishingCountry":"BR","protocol":"DIGIR","lastCrawled":"2013-09-07T07:05:27.000+0000","crawlId":1,"extensions":{},"basisOfRecord":"PRESERVED_SPECIMEN","taxonKey":1340307,"kingdomKey":1,"phylumKey":54,"classKey":216,"orderKey":1457,"familyKey":4334,"genusKey":1340278,"speciesKey":1340307,"scientific'

# %%
# or, get results as a dictionary (JSON converted)
rdict = response.json()

# get some quick info on the dictionary items
list(rdict.keys())
# Out:
# ['offset', 'limit', 'endOfRecords', 'count', 'results', 'facets']

# %% [markdown]
# ### Parsing the results
# In GBIF our response can be parsed into a dictionary object using the JSON format, and this as six keys shown above. These are explained in the API docs, and correspond to information about what records are available for our query. However, it did not return *all* of the data for those records to us yet. That would be too easy. Instead, databases usually have limits on the amount of data from each request as a way of limiting the bandwidth they will need for sending the data, and to make it faster. For GBIF the default number, shown under the "limit" key, is 20. And the default starting position, shown under "offset" is 0. The total number of records is in "count". So for *Bombus*, as we show below, there are 1,048,303 records, but on records 1-20 were returned to us so far.

# %%
## how many records are there for this query
rdict["count"]
# Out:
# 1048304

# %%
## how many records were returned
rdict["limit"]
# Out:
# 20

# %%
## starting from which record
rdict["offset"]
# Out:
# 0

# %% [markdown]
# ### So where's the data?
# It's stored under the `results` variable, and is returned as a list of dictionaries, where each dictionary is a record with lots of information. Below I show the first record from our search.

# %%
# here is the first record, it's also a dictionary
rdict["results"][0]
# Out:
# {'basisOfRecord': 'PRESERVED_SPECIMEN',
#  'catalogNumber': '6416',
#  'class': 'Insecta',
#  'classKey': 216,
#  'collectionCode': 'CEPANN',
#  'continent': 'SOUTH_AMERICA',
#  'country': 'Brazil',
#  'countryCode': 'BR',
#  'crawlId': 1,
#  'datasetKey': '86aba78e-f762-11e1-a439-00145eb45e9a',
#  'decimalLatitude': 0.0,
#  'decimalLongitude': 0.0,
#  'extensions': {},
#  'facts': [],
#  'family': 'Apidae',
#  'familyKey': 4334,
#  'gbifID': '131330107',
#  'genericName': 'Bombus',
#  'genus': 'Bombus',
#  'genusKey': 1340278,
#  'geodeticDatum': 'WGS84',
#  'identifiers': [],
#  'institutionCode': 'USP',
#  'issues': ['ZERO_COORDINATE',
#   'GEODETIC_DATUM_ASSUMED_WGS84',
#   'COUNTRY_COORDINATE_MISMATCH'],
#  'key': 131330107,
#  'kingdom': 'Animalia',
#  'kingdomKey': 1,
#  'lastCrawled': '2013-09-07T07:05:27.000+0000',
#  'lastInterpreted': '2018-02-04T02:00:19.037+0000',
#  'license': 'http://creativecommons.org/licenses/by/4.0/legalcode',
#  'order': 'Hymenoptera',
#  'orderKey': 1457,
#  'phylum': 'Arthropoda',
#  'phylumKey': 54,
#  'protocol': 'DIGIR',
#  'publishingCountry': 'BR',
#  'publishingOrgKey': '8595cd50-87c0-11dc-bb35-b8a03c50a862',
#  'recordedBy': '-',
#  'relations': [],
#  'scientificName': 'Bombus morio (Swederus, 1787)',
#  'species': 'Bombus morio',
#  'speciesKey': 1340307,
#  'specificEpithet': 'morio',
#  'taxonKey': 1340307,
#  'taxonRank': 'SPECIES'}

# %%
# or to see it prettier, convert records to a DataFrame
pd.DataFrame(rdict["results"]).head()
# Out:
#         basisOfRecord catalogNumber    class  classKey collectionCode  \
# 0  PRESERVED_SPECIMEN          6416  Insecta       216         CEPANN
# 1  PRESERVED_SPECIMEN          9002  Insecta       216          CEMeC
# 2             UNKNOWN         43781  Insecta       216    2007_Mongol
# 3  PRESERVED_SPECIMEN         91583  Insecta       216            ZEN
# 4  PRESERVED_SPECIMEN         94807  Insecta       216            ZEN
#
#        continent country countryCode    county  crawlId    ...     \
# 0  SOUTH_AMERICA  Brazil          BR       NaN        1    ...
# 1            NaN  Brazil          BR  Milagres        1    ...
# 2            NaN     NaN        None       NaN       12    ...
# 3            NaN     NaN        None       NaN       17    ...
# 4            NaN     NaN        None       NaN       17    ...
#
#                        publishingOrgKey  recordedBy  relations  \
# 0  8595cd50-87c0-11dc-bb35-b8a03c50a862           -         []
# 1  8595cd50-87c0-11dc-bb35-b8a03c50a862         NaN         []
# 2  be11c6a0-7cf5-11dc-92cb-b8a03c50a862         NaN         []
# 3  4c415e40-1e21-11de-9e40-a0d6ecebb8bf         NaN         []
# 4  4c415e40-1e21-11de-9e40-a0d6ecebb8bf         NaN         []
#
#                   scientificName             species speciesKey  \
# 0  Bombus morio (Swederus, 1787)        Bombus morio  1340307.0
# 1  Bombus morio (Swederus, 1787)        Bombus morio  1340307.0
# 2    Bombus margreiteri Skorikov  Bombus margreiteri  9055570.0
# 3         Bombus Latreille, 1802                 NaN        NaN
# 4         Bombus Latreille, 1802                 NaN        NaN
#
#    specificEpithet stateProvince taxonKey taxonRank
# 0            morio           NaN  1340307   SPECIES
# 1            morio         Bahia  1340307   SPECIES
# 2      margreiteri           NaN  9055570   SPECIES
# 3              NaN           NaN  1340278     GENUS
# 4              NaN           NaN  1340278     GENUS
#
# [5 rows x 56 columns]

# %% [markdown]
# ### Building a request
# Here we add more arguments to further filter the results. To see which options are available, you can either look at the results from our existing calls so far, or you can read further into the API docs. Sometimes API docs will be incomplete though, so it can be useful to learn to try to infer which options are possible from looking at the results. A more complex search is accomplished by building a URL that has more key:value pairs each appended to the end of the URL, and separated by a "&" symbol. For large searches it begins to get difficult to write out by hand, and that is where `requests` comes in handy. Here we enter the additional arguments we want using a simple python dictionary into the entry 'params'. Below I show the URL for when we add the requirement that a record have coordinate data, and for when we add additional arguments to raise the limit for the number of records returned. The max records at a time (limit - offset) is 300. Above that you need to increment the offset to search higher values.

# %%
# add requirement that the record have coordinate data
res = requests.get(
    url=baseurl, 
    params={
        "q": "Bombus", 
        "hasCoordinate": "true",
    }
)
res.url
# Out:
# 'http://api.gbif.org/v1/occurrence/search?q=Bombus&hasCoordinate=true'

# %%
# request records 0-100
res = requests.get(
    url=baseurl, 
    params={
        "q": "Bombus", 
        "hasCoordinate": "true",
        "offset": "0", 
        "limit": "100"
    }
)
res.url
# Out:
# 'http://api.gbif.org/v1/occurrence/search?q=Bombus&hasCoordinate=true&offset=0&limit=100'

# %% [markdown]
# ### A complex search
# Here I request all Bombus records from 1900-1910 that are associated with a preserved speciment (as opposed to HUMAN_OBSERVATION or FOSSIL_SPECIMEN), has spatial data, and is in the US. The 'count' shows us that there are 4,977 records meeting these requirements. We requested the max of 300 records.

# %%
res = requests.get(
    url=baseurl, 
    params={
        "q": "Bombus", 
        "year": "1900,1910", 
        "basisOfRecord": "PRESERVED_SPECIMEN",
        "hasCoordinate": "true",
        "hasGeospatialIssue": "false",
        "country": "US",
        "offset": "0",
        "limit": "300"
    },
)
r2dict = res.json()
r2dict["count"]
# Out:
# 4977

# %%
res = requests.get(
    url=baseurl, 
    params={
        "q": "Bombus", 
        "year": "1900,1910", 
        "basisOfRecord": "PRESERVED_SPECIMEN",
        "hasCoordinate": "true",
        "hasGeospatialIssue": "false",
        "country": "US",
        "offset": "300",
        "limit": "300"
    },
)
r1dict = res.json()
r1dict["count"]
# Out:
# 4977

# %% [markdown]
# ### Combining many searches
# If we wanted to collect all records for a given search then we need to increment the "offset" argument until we reach the end of the records. Each is returned as a list of dictionaries, so we can just join all of those lists together and return them.

# %%
def get_all_records(searchparams):
    "iterate until end of records"
    start = 0
    data = []
    
    while 1:
        # make request and store results
        res = requests.get(
            url=baseurl, 
            params=searchparams,
        )
        # increment counter
        searchparams["offset"] = str(int(searchparams["offset"]) + 300)
        
        # concatenate data 
        idata = res.json()
        data += idata["results"]
        
        # stop when end of record is reached
        if idata["endOfRecords"]:
            break
        
    return data

# %%
# make params dictionary
searchparams = {
    "q": "Bombus", 
    "year": "1900,1905", 
    "basisOfRecord": "PRESERVED_SPECIMEN",
    "hasCoordinate": "true",
    "hasGeospatialIssue": "false",
    "country": "US",
    "offset": "0",
    "limit": "300"
}

# call function to search over all offset values until end
data = get_all_records(searchparams)

# %% [markdown]
# ### The full data

# %%
# convert to a data frame
df = pd.DataFrame(data)

# %%
# keys (columns) in the dataframe (there are many!)
list(df.columns)
# Out:
# ['accessRights',
#  'associatedReferences',
#  'associatedTaxa',
#  'basisOfRecord',
#  'bibliographicCitation',
#  'catalogNumber',
#  'class',
#  'classKey',
#  'collectionCode',
#  'collectionID',
#  'continent',
#  'coordinatePrecision',
#  'coordinateUncertaintyInMeters',
#  'country',
#  'countryCode',
#  'county',
#  'crawlId',
#  'datasetID',
#  'datasetKey',
#  'datasetName',
#  'dateIdentified',
#  'day',
#  'decimalLatitude',
#  'decimalLongitude',
#  'dynamicProperties',
#  'elevation',
#  'elevationAccuracy',
#  'endDayOfYear',
#  'eventDate',
#  'eventRemarks',
#  'extensions',
#  'facts',
#  'family',
#  'familyKey',
#  'fieldNotes',
#  'gbifID',
#  'genericName',
#  'genus',
#  'genusKey',
#  'geodeticDatum',
#  'georeferenceProtocol',
#  'georeferenceRemarks',
#  'georeferenceSources',
#  'georeferencedBy',
#  'higherClassification',
#  'higherGeography',
#  'identifiedBy',
#  'identifier',
#  'identifiers',
#  'individualCount',
#  'infraspecificEpithet',
#  'institutionCode',
#  'institutionID',
#  'issues',
#  'key',
#  'kingdom',
#  'kingdomKey',
#  'language',
#  'lastCrawled',
#  'lastInterpreted',
#  'lastParsed',
#  'license',
#  'lifeStage',
#  'locality',
#  'media',
#  'modified',
#  'month',
#  'nomenclaturalCode',
#  'occurrenceID',
#  'occurrenceRemarks',
#  'order',
#  'orderKey',
#  'organismID',
#  'ownerInstitutionCode',
#  'phylum',
#  'phylumKey',
#  'preparations',
#  'previousIdentifications',
#  'protocol',
#  'publishingCountry',
#  'publishingOrgKey',
#  'recordedBy',
#  'references',
#  'relations',
#  'rightsHolder',
#  'samplingProtocol',
#  'scientificName',
#  'scientificNameID',
#  'sex',
#  'source',
#  'species',
#  'speciesKey',
#  'specificEpithet',
#  'startDayOfYear',
#  'stateProvince',
#  'taxonKey',
#  'taxonRank',
#  'taxonRemarks',
#  'type',
#  'typeStatus',
#  'verbatimEventDate',
#  'vernacularName',
#  'year']

# %%
# view just the columns we're interested in for now.
sdf = df[["species", "year", "decimalLatitude", "decimalLongitude"]]
sdf.head()
# Out:
#              species  year  decimalLatitude  decimalLongitude
# 0      Bombus vagans  1905         42.09606         -90.16255
# 1   Bombus centralis  1902         47.94167        -119.00222
# 2      Bombus vagans  1905         42.09606         -90.16255
# 3  Bombus nevadensis  1905         46.73139        -117.17861
# 4   Bombus impatiens  1905         41.86750         -90.15940

# %%
# how many records?
sdf.shape
# Out:
# (2009, 4)

# %%
# which unique species?
sdf.species.unique()
# Out:
# array(['Bombus vagans', 'Bombus centralis', 'Bombus nevadensis',
#        'Bombus impatiens', 'Bombus appositus', 'Bombus variabilis',
#        'Bombus griseocollis', 'Bombus huntii', 'Bombus rufocinctus',
#        'Bombus ternarius', 'Bombus ashtoni', 'Bombus fraternus',
#        'Bombus pensylvanicus', 'Bombus bifarius', 'Bombus affinis',
#        'Bombus borealis', 'Bombus morrisoni', 'Bombus citrinus',
#        'Bombus terricola', 'Bombus perplexus', 'Bombus fernaldae',
#        'Bombus melanopygus', 'Bombus sylvicola', 'Bombus fervidus',
#        'Bombus auricomus', 'Bombus sandersoni', 'Bombus mixtus',
#        'Bombus vosnesenskii', 'Bombus crotchii', 'Bombus insularis',
#        'Bombus bimaculatus', 'Bombus occidentalis', 'Bombus cockerelli',
#        nan, 'Bombus balteatus', 'Bombus lapponicus',
#        'Bombus californicus', 'Bombus suckleyi', 'Bombus patagiatus',
#        'Bombus flavifrons', 'Bombus sitkensis', 'Bombus neoboreus',
#        'Bombus rufosuffusus', 'Bombus separatus'], dtype=object)

# %%
# exclude nan and count species
mask = sdf.species.notna()
df.species[mask].unique().size
# Out:
# 43

# %%
# plot the number of each species in order
sp_counts = df.species[mask].value_counts()
toyplot.bars(sp_counts, height=350, title=sp_counts.index);
# Out:
# <div class="toyplot" id="t6b980dd299c44948927b63522bbc319b" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="350.0px" id="t3c535d44f3e040118c8b3fa5b1ed1744" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 350.0" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t62b5347b3f644d7083e803a49dc51a4a"><clipPath id="tb5310ca2fec844fbb3f7b99f9a64ff61"><rect height="270.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#tb5310ca2fec844fbb3f7b99f9a64ff61)"><g class="toyplot-mark-BarMagnitudes" id="t96b8bf27d7d644d5a383d64de7dac922" style="stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><g class="toyplot-Series"><rect class="toyplot-Datum" height="250.0" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="11.627906976744178" x="50.0" y="50.0"><title>Bombus impatiens</title></rect><rect class="toyplot-Datum" height="218.88888888888889" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="11.627906976744192" x="61.62790697674418" y="81.11111111111111"><title>Bombus vagans</title></rect><rect class="toyplot-Datum" height="181.11111111111111" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="11.627906976744185" x="73.25581395348837" y="118.88888888888889"><title>Bombus occidentalis</title></rect><rect class="toyplot-Datum" height="164.44444444444446" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="11.627906976744185" x="84.88372093023256" y="135.55555555555554"><title>Bombus pensylvanicus</title></rect><rect class="toyplot-Datum" height="163.33333333333334" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="11.627906976744185" x="96.51162790697674" y="136.66666666666666"><title>Bombus fervidus</title></rect><rect class="toyplot-Datum" height="108.88888888888886" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="11.627906976744185" x="108.13953488372093" y="191.11111111111114"><title>Bombus griseocollis</title></rect><rect class="toyplot-Datum" height="104.44444444444446" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="11.627906976744185" x="119.76744186046511" y="195.55555555555554"><title>Bombus affinis</title></rect><rect class="toyplot-Datum" height="97.77777777777777" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="11.627906976744185" x="131.3953488372093" y="202.22222222222223"><title>Bombus terricola</title></rect><rect class="toyplot-Datum" height="92.22222222222223" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="11.627906976744185" x="143.02325581395348" y="207.77777777777777"><title>Bombus centralis</title></rect><rect class="toyplot-Datum" height="81.11111111111109" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="11.627906976744185" x="154.65116279069767" y="218.8888888888889"><title>Bombus morrisoni</title></rect><rect class="toyplot-Datum" height="75.55555555555554" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0 ...

# %% [markdown]
# ## Assignment:

# %% [markdown]
# ### Task 1:
# Write a Class object called `Records` that can be given a taxon name query and a range of years and will return a class instance with all results from GBIF for the queried range using the same params from our example above, except allowing the 'q' and 'year' arguments to vary. You can reuse the code above to create the core functions for your object. When finished, you should be able to use the object in the following way. This means that after writing your Class object, test it using the code below and make sure it gives proper results.

# %%
# fill in the params dictionary, write functions to update it
# with the entered arguments to __init__, write functions
# to get_all_records and store results as a dataframe.
# have all functions run during init so that the initialized
# object calls the request and returns a full dataframe. 


class Records:
    def __init__(self, q=None, interval=None):

        self.q = q
        self.interval = interval
        self.params = {
            # Where interval is given by initial year and final year separated
            # by a comma
            "q": self.q,
            "year": self.interval,
            "basisOfRecord": "PRESERVED_SPECIMEN",
            "hasCoordinate": "true",
            "hasGeospatialIssue": "false",
            "country": "US",
            "offset": "0",
            "limit": "300"
            }
        self.df = self.get_all_records()

    def get_all_records(self):
        "iterate until end of records"
        start = 0
        data = []

        while 1:
            # make request and store results
            res = requests.get(
                url="http://api.gbif.org/v1/occurrence/search?",
                params=self.params,
            )
            # increment counter
            self.params["offset"] = str(int(self.params["offset"]) + 300)

            # concatenate data
            idata = res.json()
            data += idata["results"]

            # stop when end of record is reached
            if idata["endOfRecords"]:
                break

            return pd.DataFrame(data)

# %%
## create instance by entering query and a range of years as integers
rec = Record("Bombus", (1950, 1955))

## access all of the returned records as a dataframe 
## (here asking for the shape to see how many records there are)
rec.df.shape
# Out:
# (300, 56)

# %%
rec.df
# Out:
#           basisOfRecord             catalogNumber    class  classKey  \
# 0    PRESERVED_SPECIMEN  Insect Collection 334996  Insecta       216
# 1    PRESERVED_SPECIMEN  Insect Collection 248416  Insecta       216
# 2    PRESERVED_SPECIMEN  Insect Collection 253783  Insecta       216
# 3    PRESERVED_SPECIMEN  Insect Collection 253782  Insecta       216
# 4    PRESERVED_SPECIMEN  Insect Collection 253790  Insecta       216
# 5    PRESERVED_SPECIMEN  Insect Collection 334995  Insecta       216
# 6    PRESERVED_SPECIMEN  Insect Collection 253785  Insecta       216
# 7    PRESERVED_SPECIMEN  Insect Collection 253793  Insecta       216
# 8    PRESERVED_SPECIMEN  Insect Collection 257250  Insecta       216
# 9    PRESERVED_SPECIMEN  Insect Collection 253787  Insecta       216
# 10   PRESERVED_SPECIMEN  Insect Collection 253792  Insecta       216
# 11   PRESERVED_SPECIMEN  Insect Collection 333347  Insecta       216
# 12   PRESERVED_SPECIMEN  Insect Collection 242683  Insecta       216
# 13   PRESERVED_SPECIMEN  Insect Collection 334986  Insecta       216
# 14   PRESERVED_SPECIMEN  Insect Collection 334994  Insecta       216
# 15   PRESERVED_SPECIMEN  Insect Collection 253791  Insecta       216
# 16   PRESERVED_SPECIMEN  Insect Collection 253521  Insecta       216
# 17   PRESERVED_SPECIMEN  Insect Collection 257249  Insecta       216
# 18   PRESERVED_SPECIMEN                BBSL225692  Insecta       216
# 19   PRESERVED_SPECIMEN               BOMBUS18677  Insecta       216
# 20   PRESERVED_SPECIMEN               BOMBUS21550  Insecta       216
# 21   PRESERVED_SPECIMEN               BOMBUS29530  Insecta       216
# 22   PRESERVED_SPECIMEN               BOMBUS29533  Insecta       216
# 23   PRESERVED_SPECIMEN               BOMBUS32763  Insecta       216
# 24   PRESERVED_SPECIMEN                BOMBUS5977  Insecta       216
# 25   PRESERVED_SPECIMEN                BOMBUS3284  Insecta       216
# 26   PRESERVED_SPECIMEN                     89796  Insecta       216
# 27   PRESERVED_SPECIMEN               BOMBUS19030  Insecta       216
# 28   PRESERVED_SPECIMEN               BOMBUS21677  Insecta       216
# 29   PRESERVED_SPECIMEN               BOMBUS29517  Insecta       216
# ..                  ...                       ...      ...       ...
# 270  PRESERVED_SPECIMEN                     90237  Insecta       216
# 271  PRESERVED_SPECIMEN                     89428  Insecta       216
# 272  PRESERVED_SPECIMEN               BOMBUS17506  Insecta       216
# 273  PRESERVED_SPECIMEN               BOMBUS18111  Insecta       216
# 274  PRESERVED_SPECIMEN               BOMBUS20534  Insecta       216
# 275  PRESERVED_SPECIMEN               BOMBUS29520  Insecta       216
# 276  PRESERVED_SPECIMEN               BOMBUS29569  Insecta       216
# 277  PRESERVED_SPECIMEN                BBSL220829  Insecta       216
# 278  PRESERVED_SPECIMEN               BOMBUS19058  Insecta       216
# 279  PRESERVED_SPECIMEN              OS0000131469  Insecta       216
# 280  PRESERVED_SPECIMEN               BOMBUS29300  Insecta       216
# 281  PRESERVED_SPECIMEN               BOMBUS23039  Insecta       216
# 282  PRESERVED_SPECIMEN                BOMBUS3718  Insecta       216
# 283  PRESERVED_SPECIMEN                BOMBUS3726  Insecta       216
# 284  PRESERVED_SPECIMEN               BOMBUS37467  Insecta       216
# 285  PRESERVED_SPECIMEN               BOMBUS31701  Insecta       216
# 286  PRESERVED_SPECIMEN                     89858  Insecta       216
# 287  PRESERVED_SPECIMEN               BOMBUS28132  Insecta       216
# 288  PRESERVED_SPECIMEN               BOMBUS29110  Insecta       216
# 289  PRESERVED_SPECIMEN               BOMBUS29079  Insecta       216
# 290  PRESERVED_SPECIMEN               BOMBUS29545  Insecta       216
# 291  PRESERVED_SPECIMEN               BOMBUS22982  Insecta       216
# 292  PRESERVED_SPECIMEN               BOMBUS23375  Insecta       216
# 293  PRESERVED_SPECIMEN               BOMBUS17415  Insecta       216
# 294  PRESERVED_SPECIMEN                BOMBUS3438  Insecta       216
# 295  PRESERVED_SPECIMEN                BOMBUS3460  Insecta       216
# 296  PRESERVED_SPECIMEN                     90754  Insecta       216
# 297  PRESERVED_SPECIMEN                    451387  Insecta       216
# 298  PRESERVED_SPECIMEN              USNM00471169  Insecta       216
# 299  PRESERVED_SPECIMEN               BOMBUS32462  Insecta       216
#
#         collectionCode      continent        country countryCode  \
# 0    Insect Collection            NaN  United States          US
# 1    Insect Collection            NaN  United States          US
# 2    Insect Collection            NaN  United States          US
# 3    Insect Collection            NaN  United States          US
# 4    Insect Collection            NaN  United States          US
# 5    Insect Collection            NaN  United States          US
# 6    Insect Collection            NaN  United States          US
# 7    Insect Collection            NaN  United States          US
# 8    Insect Collection            NaN  United States          US
# 9    Insect Collection            NaN  United States          US
# 10   Insect Collection            NaN  United States          US
# 11   Insect Collection            NaN  United States          US
# 12   Insect Collection            NaN  United States          US
# 13   Insect Collection            NaN  United States          US
# 14   Insect Collection            NaN  United States          US
# 15   Insect Collection            NaN  United States          US
# 16   Insect Collection            NaN  United States          US
# 17   Insect Collection            NaN  United States          US
# 18                BBSL            NaN  United States          US
# 19                BBSL            NaN  United States          US
# 20                BBSL            NaN  United States          US
# 21                BBSL            NaN  United States          US
# 22                BBSL            NaN  United States          US
# 23                BBSL            NaN  United States          US
# 24                BBSL            NaN  United States          US
# 25                BBSL            NaN  United States          US
# 26                BBSL            NaN  United States          US
# 27                BBSL            NaN  United States          US
# 28                BBSL            NaN  United States          US
# 29                BBSL            NaN  United States          US
# ..                 ...            ...            ...         ...
# 270               BBSL            NaN  United States          US
# 271               BBSL            NaN  United States          US
# 272               BBSL            NaN  United States          US
# 273               BBSL            NaN  United States          US
# 274               BBSL            NaN  United States          US
# 275               BBSL            NaN  United States          US
# 276               BBSL            NaN  United States          US
# 277               BBSL            NaN  United States          US
# 278               BBSL            NaN  United States          US
# 279               BBSL            NaN  United States          US
# 280               BBSL            NaN  United States          US
# 281               BBSL            NaN  United States          US
# 282               BBSL            NaN  United States          US
# 283               BBSL            NaN  United States          US
# 284               BBSL            NaN  United States          US
# 285               BBSL            NaN  United States          US
# 286               BBSL            NaN  United States          US
# 287               BBSL            NaN  United States          US
# 288               BBSL            NaN  United States          US
# 289               BBSL            NaN  United States          US
# 290               BBSL            NaN  United States          US
# 291               BBSL            NaN  United States          US
# 292               BBSL            NaN  United States          US
# 293               BBSL            NaN  United States          US
# 294               BBSL            NaN  United States          US
# 295               BBSL            NaN  United States          US
# 296               BBSL            NaN  United States          US
# 297          Bumblebee  NORTH_AMERICA  United States          US
# 298               BBSL            NaN  United States          US
# 299               BBSL            NaN  United States          US
#
#                 county  crawlId  ...       recordedBy  relations  \
# 0                Adams        1  ...              NaN         []
# 1           Tippecanoe        1  ...              NaN         []
# 2                Adams        1  ...              NaN         []
# 3                Adams        1  ...              NaN         []
# 4                Adams        1  ...              NaN         []
# 5                Adams        1  ...              NaN         []
# 6                Adams        1  ...              NaN         []
# 7                Adams        1  ...              NaN         []
# 8               Benton        1  ...              NaN         []
# 9                Adams        1  ...              NaN         []
# 10               Adams        1  ...              NaN         []
# 11              Warren        1  ...              NaN         []
# 12               Adams        1  ...              NaN         []
# 13          Tippecanoe        1  ...              NaN         []
# 14               Adams        1  ...              NaN         []
# 15               Adams        1  ...              NaN         []
# 16             Klamath        1  ...              NaN         []
# 17          Tippecanoe        1  ...              NaN         []
# 18                Iron       58  ...      G.E. Bohart         []
# 19                 NaN       56  ...              NaN         []
# 20           Menominee       56  ...              NaN         []
# 21              Ripley       56  ...              NaN         []
# 22              Ripley       56  ...              NaN         []
# 23          Washington       56  ...              NaN         []
# 24                 NaN       56  ...              NaN         []
# 25             Alachua       56  ...              NaN         []
# 26               Cache       56  ...      G.P. Taylor         []
# 27                 NaN       56  ...              NaN         []
# 28              Baraga       56  ...              NaN         []
# 29          Tippecanoe       56  ...              NaN         []
# ..                 ...      ...  ...              ...        ...
# 270              Cache       58  ...        G.A. Webb         []
# 271              Cache       58  ...    G.E. Knowlton         []
# 272                NaN       56  ...              NaN         []
# 273           Franklin       56  ...              NaN         []
# 274              Barry       56  ...              NaN         []
# 275         Tippecanoe       56  ...              NaN         []
# 276              Miami       56  ...              NaN         []
# 277              Weber       58  ...      G.E. Bohart         []
# 278                NaN       56  ...              NaN         []
# 279              Wasco       56  ...   F.F. Hasbrouck         []
# 280             Ripley       56  ...              NaN         []
# 281                NaN       56  ...              NaN         []
# 282               Wake       56  ...              NaN         []
# 283               Levy       56  ...              NaN         []
# 284                NaN       56  ...              NaN         []
# 285                NaN       56  ...              NaN         []
# 286              Cache       58  ...        K.E. Wolf         []
# 287          Cleveland       56  ...              NaN         []
# 288             Ripley       56  ...              NaN         []
# 289           Marshall       56  ...              NaN         []
# 290           Dearborn       56  ...              NaN         []
# 291                NaN       56  ...              NaN         []
# 292                NaN       56  ...              NaN         []
# 293           Atchison       56  ...              NaN         []
# 294            Alachua       56  ...              NaN         []
# 295               Levy       56  ...              NaN         []
# 296              Cache       58  ...        K.E. Wolf         []
# 297                NaN       41  ...        J.Sanjean         []
# 298  Matanuska-Susitna       56  ...              NaN         []
# 299             Brazos       56  ...              NaN         []
#
#                              scientificName               species  speciesKey  \
# 0         Bombus variabilis (Cresson, 1872)     Bombus variabilis   1340448.0
# 1                 Bombus vagans Smith, 1854         Bombus vagans   1340472.0
# 2            Bombus impatiens Cresson, 1863      Bombus impatiens   1340350.0
# 3                 Bombus vagans Smith, 1854         Bombus vagans   1340472.0
# 4        Bombus griseocollis (DeGeer, 1773)   Bombus griseocollis   1340409.0
# 5         Bombus variabilis (Cresson, 1872)     Bombus variabilis   1340448.0
# 6            Bombus impatiens Cresson, 1863      Bombus impatiens   1340350.0
# 7      Bombus pensylvanicus (De Geer, 1773)  Bombus pensylvanicus   1340416.0
# 8            Bombus impatiens Cresson, 1863      Bombus impatiens   1340350.0
# 9        Bombus griseocollis (DeGeer, 1773)   Bombus griseocollis   1340409.0
# 10       Bombus griseocollis (DeGeer, 1773)   Bombus griseocollis   1340409.0
# 11           Bombus impatiens Cresson, 1863      Bombus impatiens   1340350.0
# 12           Bombus fraternus (Smith, 1854)      Bombus fraternus   1340432.0
# 13        Bombus variabilis (Cresson, 1872)     Bombus variabilis   1340448.0
# 14        Bombus variabilis (Cresson, 1872)     Bombus variabilis   1340448.0
# 15     Bombus pensylvanicus (De Geer, 1773)  Bombus pensylvanicus   1340416.0
# 16         Bombus rufocinctus Cresson, 1863    Bombus rufocinctus   1340347.0
# 17     Bombus pensylvanicus (De Geer, 1773)  Bombus pensylvanicus   1340416.0
# 18           Bombus morrisoni Cresson, 1878      Bombus morrisoni   1340475.0
# 19     Bombus pensylvanicus (De Geer, 1773)  Bombus pensylvanicus   1340416.0
# 20             Bombus terricola Kirby, 1837      Bombus terricola   1340493.0
# 21           Bombus impatiens Cresson, 1863      Bombus impatiens   1340350.0
# 22           Bombus impatiens Cresson, 1863      Bombus impatiens   1340350.0
# 23     Bombus pensylvanicus (De Geer, 1773)  Bombus pensylvanicus   1340416.0
# 24           Bombus impatiens Cresson, 1863      Bombus impatiens   1340350.0
# 25     Bombus pensylvanicus (De Geer, 1773)  Bombus pensylvanicus   1340416.0
# 26         Bombus occidentalis Greene, 1858   Bombus occidentalis   1340429.0
# 27     Bombus pensylvanicus (De Geer, 1773)  Bombus pensylvanicus   1340416.0
# 28             Bombus terricola Kirby, 1837      Bombus terricola   1340493.0
# 29           Bombus impatiens Cresson, 1863      Bombus impatiens   1340350.0
# ..                                      ...                   ...         ...
# 270       Bombus fervidus (Fabricius, 1798)       Bombus fervidus   1340478.0
# 271          Bombus insularis (Smith, 1861)      Bombus insularis   1340331.0
# 272    Bombus pensylvanicus (De Geer, 1773)  Bombus pensylvanicus   1340416.0
# 273    Bombus pensylvanicus (De Geer, 1773)  Bombus pensylvanicus   1340416.0
# 274        Bombus bimaculatus Cresson, 1863    Bombus bimaculatus   1340382.0
# 275          Bombus impatiens Cresson, 1863      Bombus impatiens   1340350.0
# 276          Bombus impatiens Cresson, 1863      Bombus impatiens   1340350.0
# 277          Bombus appositus Cresson, 1878      Bombus appositus   1340470.0
# 278        Bombus bimaculatus Cresson, 1863    Bombus bimaculatus   1340382.0
# 279  Bombus vosnesenskii Radoszkowski, 1862   Bombus vosnesenskii   1340436.0
# 280        Bombus bimaculatus Cresson, 1863    Bombus bimaculatus   1340382.0
# 281          Bombus impatiens Cresson, 1863      Bombus impatiens   1340350.0
# 282          Bombus impatiens Cresson, 1863      Bombus impatiens   1340350.0
# 283          Bombus impatiens Cresson, 1863      Bombus impatiens   1340350.0
# 284            Bombus terricola Kirby, 1837      Bombus terricola   1340493.0
# 285          Bombus impatiens Cresson, 1863      Bombus impatiens   1340350.0
# 286          Bombus appositus Cresson, 1878      Bombus appositus   1340470.0
# 287          Bombus fraternus (Smith, 1854)      Bombus fraternus   1340432.0
# 288    Bombus pensylvanicus (De Geer, 1773)  Bombus pensylvanicus   1340416.0
# 289    Bombus pensylvanicus (De Geer, 1773)  Bombus pensylvanicus   1340416.0
# 290          Bombus impatiens Cresson, 1863      Bombus impatiens   1340350.0
# 291          Bombus impatiens Cresson, 1863      Bombus impatiens   1340350.0
# 292          Bombus impatiens Cresson, 1863      Bombus impatiens   1340350.0
# 293          Bombus impatiens Cresson, 1863      Bombus impatiens   1340350.0
# 294    Bombus pensylvanicus (De Geer, 1773)  Bombus pensylvanicus   1340416.0
# 295          Bombus impatiens Cresson, 1863      Bombus impatiens   1340350.0
# 296          Bombus centralis Cresson, 1864      Bombus centralis   1340324.0
# 297       Bombus fervidus (Fabricius, 1798)       Bombus fervidus   1340478.0
# 298        Bombus occidentalis Greene, 1858   Bombus occidentalis   1340429.0
# 299    Bombus pensylvanicus (De Geer, 1773)  Bombus pensylvanicus   1340416.0
#
#     specificEpithet   stateProvince taxonKey taxonRank  year
# 0        variabilis        Illinois  1340448   SPECIES  1950
# 1            vagans         Indiana  1340472   SPECIES  1950
# 2         impatiens        Illinois  1340350   SPECIES  1950
# 3            vagans        Illinois  1340472   SPECIES  1950
# 4      griseocollis        Illinois  1340409   SPECIES  1950
# 5        variabilis        Illinois  1340448   SPECIES  1950
# 6         impatiens        Illinois  1340350   SPECIES  1950
# 7     pensylvanicus        Illinois  1340416   SPECIES  1950
# 8         impatiens         Indiana  1340350   SPECIES  1950
# 9      griseocollis        Illinois  1340409   SPECIES  1950
# 10     griseocollis        Illinois  1340409   SPECIES  1950
# 11        impatiens         Indiana  1340350   SPECIES  1950
# 12        fraternus        Illinois  1340432   SPECIES  1950
# 13       variabilis         Indiana  1340448   SPECIES  1950
# 14       variabilis        Illinois  1340448   SPECIES  1950
# 15    pensylvanicus        Illinois  1340416   SPECIES  1950
# 16      rufocinctus          Oregon  1340347   SPECIES  1950
# 17    pensylvanicus         Indiana  1340416   SPECIES  1950
# 18        morrisoni            Utah  1340475   SPECIES  1950
# 19    pensylvanicus     Mississippi  1340416   SPECIES  1950
# 20        terricola        Michigan  1340493   SPECIES  1955
# 21        impatiens         Indiana  1340350   SPECIES  1950
# 22        impatiens         Indiana  1340350   SPECIES  1950
# 23    pensylvanicus        Arkansas  1340416   SPECIES  1955
# 24        impatiens            Iowa  1340350   SPECIES  1950
# 25    pensylvanicus         Florida  1340416   SPECIES  1955
# 26     occidentalis            Utah  1340429   SPECIES  1950
# 27    pensylvanicus     Mississippi  1340416   SPECIES  1950
# 28        terricola        Michigan  1340493   SPECIES  1955
# 29        impatiens         Indiana  1340350   SPECIES  1950
# ..              ...             ...      ...       ...   ...
# 270        fervidus            Utah  1340478   SPECIES  1950
# 271       insularis            Utah  1340331   SPECIES  1950
# 272   pensylvanicus          Kansas  1340416   SPECIES  1950
# 273   pensylvanicus          Kansas  1340416   SPECIES  1950
# 274     bimaculatus        Michigan  1340382   SPECIES  1955
# 275       impatiens         Indiana  1340350   SPECIES  1950
# 276       impatiens         Indiana  1340350   SPECIES  1950
# 277       appositus            Utah  1340470   SPECIES  1950
# 278     bimaculatus     Mississippi  1340382   SPECIES  1950
# 279    vosnesenskii          Oregon  1340436   SPECIES  1955
# 280     bimaculatus         Indiana  1340382   SPECIES  1950
# 281       impatiens        Virginia  1340350   SPECIES  1955
# 282       impatiens  North Carolina  1340350   SPECIES  1955
# 283       impatiens         Florida  1340350   SPECIES  1955
# 284       terricola       Minnesota  1340493   SPECIES  1955
# 285       impatiens        Virginia  1340350   SPECIES  1950
# 286       appositus            Utah  1340470   SPECIES  1950
# 287       fraternus        Oklahoma  1340432   SPECIES  1950
# 288   pensylvanicus         Indiana  1340416   SPECIES  1950
# 289   pensylvanicus         Indiana  1340416   SPECIES  1950
# 290       impatiens         Indiana  1340350   SPECIES  1950
# 291       impatiens  North Carolina  1340350   SPECIES  1950
# 292       impatiens  North Carolina  1340350   SPECIES  1955
# 293       impatiens          Kansas  1340350   SPECIES  1950
# 294   pensylvanicus         Florida  1340416   SPECIES  1955
# 295       impatiens         Florida  1340350   SPECIES  1955
# 296       centralis            Utah  1340324   SPECIES  1950
# 297        fervidus      Washington  1340478   SPECIES  1955
# 298    occidentalis          Alaska  1340429   SPECIES  1950
# 299   pensylvanicus           Texas  1340416   SPECIES  1955
#
# [300 rows x 56 columns]

# %% [markdown]
# ### Task 2:
# Once you have tested your Record class object in this notebook and it is working, copy it to a new `.py` file in a text editor and name it records.py, and put this in a new folder called `records/`. Then add an `__init__.py` file and a `setup.py` file and structure this directory so that it can be imported as a Python package. If you need a review on how to do this look back at lecture 5, and the assignment from that lecture (https://github.com/programming-for-bio/5-Packaging/blob/master/Notebooks/nb-5.2-packaging.ipynb). This will be very similar to the 'helloworld' package that we wrote. When you are finished, install the package with pip and try importing it like below. Then push the `records` folder as a new repo to your GitHub account named records.

# %%
# import your library and access the Records class object from it
import records
rec = records.Records("Bombus", (1990, 2000))
rec.df
# Out:
#           basisOfRecord             catalogNumber    class  classKey  \
# 0    PRESERVED_SPECIMEN  Insect Collection 405256  Insecta       216
# 1    PRESERVED_SPECIMEN  Insect Collection 245415  Insecta       216
# 2    PRESERVED_SPECIMEN               BOMBUS26394  Insecta       216
# 3    PRESERVED_SPECIMEN               BOMBUS26594  Insecta       216
# 4    PRESERVED_SPECIMEN               BOMBUS26488  Insecta       216
# 5    PRESERVED_SPECIMEN               BOMBUS23802  Insecta       216
# 6    PRESERVED_SPECIMEN               BOMBUS24171  Insecta       216
# 7    PRESERVED_SPECIMEN               BOMBUS22041  Insecta       216
# 8    PRESERVED_SPECIMEN               BOMBUS23429  Insecta       216
# 9    PRESERVED_SPECIMEN               BOMBUS23419  Insecta       216
# 10   PRESERVED_SPECIMEN               BOMBUS23810  Insecta       216
# 11   PRESERVED_SPECIMEN               BOMBUS23984  Insecta       216
# 12   PRESERVED_SPECIMEN               BOMBUS23965  Insecta       216
# 13   PRESERVED_SPECIMEN               BOMBUS23917  Insecta       216
# 14   PRESERVED_SPECIMEN               BOMBUS24942  Insecta       216
# 15   PRESERVED_SPECIMEN               BOMBUS24994  Insecta       216
# 16   PRESERVED_SPECIMEN               BOMBUS25226  Insecta       216
# 17   PRESERVED_SPECIMEN               BOMBUS25530  Insecta       216
# 18   PRESERVED_SPECIMEN               BOMBUS25583  Insecta       216
# 19   PRESERVED_SPECIMEN               BOMBUS25523  Insecta       216
# 20   PRESERVED_SPECIMEN               BOMBUS25618  Insecta       216
# 21   PRESERVED_SPECIMEN               BOMBUS37546  Insecta       216
# 22   PRESERVED_SPECIMEN               BOMBUS38497  Insecta       216
# 23   PRESERVED_SPECIMEN               BOMBUS39227  Insecta       216
# 24   PRESERVED_SPECIMEN               BOMBUS39318  Insecta       216
# 25   PRESERVED_SPECIMEN               BOMBUS38714  Insecta       216
# 26   PRESERVED_SPECIMEN               BOMBUS18372  Insecta       216
# 27   PRESERVED_SPECIMEN               BOMBUS18368  Insecta       216
# 28   PRESERVED_SPECIMEN               BOMBUS23907  Insecta       216
# 29   PRESERVED_SPECIMEN               BOMBUS23769  Insecta       216
# ..                  ...                       ...      ...       ...
# 270  PRESERVED_SPECIMEN               BOMBUS23423  Insecta       216
# 271  PRESERVED_SPECIMEN               BOMBUS23809  Insecta       216
# 272  PRESERVED_SPECIMEN               BOMBUS23804  Insecta       216
# 273  PRESERVED_SPECIMEN               BOMBUS23904  Insecta       216
# 274  PRESERVED_SPECIMEN               BOMBUS23898  Insecta       216
# 275  PRESERVED_SPECIMEN               BOMBUS23772  Insecta       216
# 276  PRESERVED_SPECIMEN               BOMBUS24340  Insecta       216
# 277  PRESERVED_SPECIMEN               BOMBUS24943  Insecta       216
# 278  PRESERVED_SPECIMEN               BOMBUS25277  Insecta       216
# 279  PRESERVED_SPECIMEN               BOMBUS25498  Insecta       216
# 280  PRESERVED_SPECIMEN               BOMBUS26094  Insecta       216
# 281  PRESERVED_SPECIMEN               BOMBUS26138  Insecta       216
# 282  PRESERVED_SPECIMEN               BOMBUS25151  Insecta       216
# 283  PRESERVED_SPECIMEN               BOMBUS31475  Insecta       216
# 284  PRESERVED_SPECIMEN               BOMBUS24421  Insecta       216
# 285  PRESERVED_SPECIMEN               BOMBUS38498  Insecta       216
# 286  PRESERVED_SPECIMEN               BOMBUS38701  Insecta       216
# 287  PRESERVED_SPECIMEN               BOMBUS39579  Insecta       216
# 288  PRESERVED_SPECIMEN               BOMBUS36049  Insecta       216
# 289  PRESERVED_SPECIMEN               BOMBUS24410  Insecta       216
# 290  PRESERVED_SPECIMEN               BOMBUS23727  Insecta       216
# 291  PRESERVED_SPECIMEN               BOMBUS23416  Insecta       216
# 292  PRESERVED_SPECIMEN               BOMBUS23417  Insecta       216
# 293  PRESERVED_SPECIMEN               BOMBUS23774  Insecta       216
# 294  PRESERVED_SPECIMEN               BOMBUS23765  Insecta       216
# 295  PRESERVED_SPECIMEN               BOMBUS24014  Insecta       216
# 296  PRESERVED_SPECIMEN               BOMBUS24339  Insecta       216
# 297  PRESERVED_SPECIMEN               BOMBUS24934  Insecta       216
# 298  PRESERVED_SPECIMEN               BOMBUS25484  Insecta       216
# 299  PRESERVED_SPECIMEN               BOMBUS25527  Insecta       216
#
#         collectionCode        country countryCode      county  crawlId  \
# 0    Insect Collection  United States          US         Lee        1
# 1    Insect Collection  United States          US   Champaign        1
# 2                 BBSL  United States          US   Lancaster       56
# 3                 BBSL  United States          US       Boone       56
# 4                 BBSL  United States          US    Saunders       56
# 5                 BBSL  United States          US   Lancaster       56
# 6                 BBSL  United States          US       Sioux       56
# 7                 BBSL  United States          US       Boone       56
# 8                 BBSL  United States          US       Dawes       56
# 9                 BBSL  United States          US       Dawes       56
# 10                BBSL  United States          US   Lancaster       56
# 11                BBSL  United States          US       Sioux       56
# 12                BBSL  United States          US       Sioux       56
# 13                BBSL  United States          US       Sioux       56
# 14                BBSL  United States          US   Lancaster       56
# 15                BBSL  United States          US   Lancaster       56
# 16                BBSL  United States          US       Boone       56
# 17                BBSL  United States          US   Lancaster       56
# 18                BBSL  United States          US       Dodge       56
# 19                BBSL  United States          US   Lancaster       56
# 20                BBSL  United States          US    Saunders       56
# 21                BBSL  United States          US  Washington       56
# 22                BBSL  United States          US      Pettis       56
# 23                BBSL  United States          US       Ozark       56
# 24                BBSL  United States          US    St.Louis       56
# 25                BBSL  United States          US       Ozark       56
# 26                BBSL  United States          US   Oktibbeha       56
# 27                BBSL  United States          US   Oktibbeha       56
# 28                BBSL  United States          US   Lancaster       56
# 29                BBSL  United States          US   Lancaster       56
# ..                 ...            ...         ...         ...      ...
# 270               BBSL  United States          US       Dawes       56
# 271               BBSL  United States          US   Lancaster       56
# 272               BBSL  United States          US   Lancaster       56
# 273               BBSL  United States          US   Lancaster       56
# 274               BBSL  United States          US   Lancaster       56
# 275               BBSL  United States          US   Lancaster       56
# 276               BBSL  United States          US       Dawes       56
# 277               BBSL  United States          US   Lancaster       56
# 278               BBSL  United States          US   Lancaster       56
# 279               BBSL  United States          US   Lancaster       56
# 280               BBSL  United States          US       Boone       56
# 281               BBSL  United States          US       Boone       56
# 282               BBSL  United States          US       Sioux       56
# 283               BBSL  United States          US   Worcester       56
# 284               BBSL  United States          US    BoxButte       56
# 285               BBSL  United States          US      Pettis       56
# 286               BBSL  United States          US       Ozark       56
# 287               BBSL  United States          US    St.Louis       56
# 288               BBSL  United States          US  Washington       56
# 289               BBSL  United States          US    BoxButte       56
# 290               BBSL  United States          US   Lancaster       56
# 291               BBSL  United States          US       Dawes       56
# 292               BBSL  United States          US       Dawes       56
# 293               BBSL  United States          US   Lancaster       56
# 294               BBSL  United States          US   Lancaster       56
# 295               BBSL  United States          US       Sioux       56
# 296               BBSL  United States          US       Dawes       56
# 297               BBSL  United States          US   Lancaster       56
# 298               BBSL  United States          US   Lancaster       56
# 299               BBSL  United States          US   Lancaster       56
#
#                                datasetKey  ...   \
# 0    68513375-3aa5-4f6f-9975-d97d56c21d61  ...
# 1    68513375-3aa5-4f6f-9975-d97d56c21d61  ...
# 2    8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 3    8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 4    8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 5    8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 6    8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 7    8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 8    8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 9    8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 10   8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 11   8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 12   8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 13   8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 14   8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 15   8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 16   8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 17   8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 18   8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 19   8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 20   8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 21   8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 22   8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 23   8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 24   8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 25   8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 26   8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 27   8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 28   8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 29   8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# ..                                    ...  ...
# 270  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 271  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 272  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 273  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 274  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 275  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 276  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 277  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 278  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 279  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 280  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 281  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 282  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 283  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 284  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 285  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 286  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 287  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 288  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 289  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 290  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 291  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 292  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 293  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 294  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 295  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 296  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 297  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 298  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
# 299  8c04889e-a0ad-4f39-8623-06aa9cf0131d  ...
#
#                          publishingOrgKey  relations  \
# 0    fd0038d0-3e7b-11d9-8439-b8a03c50a862         []
# 1    fd0038d0-3e7b-11d9-8439-b8a03c50a862         []
# 2    1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 3    1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 4    1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 5    1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 6    1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 7    1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 8    1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 9    1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 10   1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 11   1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 12   1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 13   1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 14   1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 15   1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 16   1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 17   1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 18   1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 19   1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 20   1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 21   1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 22   1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 23   1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 24   1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 25   1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 26   1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 27   1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 28   1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 29   1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# ..                                    ...        ...
# 270  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 271  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 272  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 273  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 274  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 275  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 276  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 277  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 278  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 279  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 280  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 281  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 282  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 283  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 284  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 285  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 286  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 287  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 288  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 289  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 290  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 291  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 292  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 293  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 294  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 295  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 296  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 297  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 298  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
# 299  1e26a630-7203-11dc-a0d8-b8a03c50a862         []
#
#                            scientificName               species speciesKey  \
# 0          Bombus impatiens Cresson, 1863      Bombus impatiens  1340350.0
# 1      Bombus auricomus (Robertson, 1903)      Bombus auricomus  1340446.0
# 2    Bombus pensylvanicus (De Geer, 1773)  Bombus pensylvanicus  1340416.0
# 3               Bombus vagans Smith, 1854         Bombus vagans  1340472.0
# 4    Bombus pensylvanicus (De Geer, 1773)  Bombus pensylvanicus  1340416.0
# 5      Bombus auricomus (Robertson, 1903)      Bombus auricomus  1340446.0
# 6      Bombus griseocollis (DeGeer, 1773)   Bombus griseocollis  1340409.0
# 7          Bombus impatiens Cresson, 1863      Bombus impatiens  1340350.0
# 8      Bombus auricomus (Robertson, 1903)      Bombus auricomus  1340446.0
# 9      Bombus auricomus (Robertson, 1903)      Bombus auricomus  1340446.0
# 10     Bombus auricomus (Robertson, 1903)      Bombus auricomus  1340446.0
# 11      Bombus fervidus (Fabricius, 1798)       Bombus fervidus  1340478.0
# 12      Bombus fervidus (Fabricius, 1798)       Bombus fervidus  1340478.0
# 13         Bombus centralis Cresson, 1864      Bombus centralis  1340324.0
# 14     Bombus griseocollis (DeGeer, 1773)   Bombus griseocollis  1340409.0
# 15     Bombus griseocollis (DeGeer, 1773)   Bombus griseocollis  1340409.0
# 16         Bombus impatiens Cresson, 1863      Bombus impatiens  1340350.0
# 17         Bombus impatiens Cresson, 1863      Bombus impatiens  1340350.0
# 18         Bombus impatiens Cresson, 1863      Bombus impatiens  1340350.0
# 19         Bombus impatiens Cresson, 1863      Bombus impatiens  1340350.0
# 20         Bombus impatiens Cresson, 1863      Bombus impatiens  1340350.0
# 21           Bombus affinis Cresson, 1863        Bombus affinis  1340481.0
# 22     Bombus auricomus (Robertson, 1903)      Bombus auricomus  1340446.0
# 23         Bombus impatiens Cresson, 1863      Bombus impatiens  1340350.0
# 24         Bombus impatiens Cresson, 1863      Bombus impatiens  1340350.0
# 25       Bombus bimaculatus Cresson, 1863    Bombus bimaculatus  1340382.0
# 26   Bombus pensylvanicus (De Geer, 1773)  Bombus pensylvanicus  1340416.0
# 27   Bombus pensylvanicus (De Geer, 1773)  Bombus pensylvanicus  1340416.0
# 28       Bombus bimaculatus Cresson, 1863    Bombus bimaculatus  1340382.0
# 29     Bombus auricomus (Robertson, 1903)      Bombus auricomus  1340446.0
# ..                                    ...                   ...        ...
# 270    Bombus auricomus (Robertson, 1903)      Bombus auricomus  1340446.0
# 271    Bombus auricomus (Robertson, 1903)      Bombus auricomus  1340446.0
# 272    Bombus auricomus (Robertson, 1903)      Bombus auricomus  1340446.0
# 273      Bombus bimaculatus Cresson, 1863    Bombus bimaculatus  1340382.0
# 274      Bombus bimaculatus Cresson, 1863    Bombus bimaculatus  1340382.0
# 275    Bombus auricomus (Robertson, 1903)      Bombus auricomus  1340446.0
# 276    Bombus griseocollis (DeGeer, 1773)   Bombus griseocollis  1340409.0
# 277    Bombus griseocollis (DeGeer, 1773)   Bombus griseocollis  1340409.0
# 278        Bombus impatiens Cresson, 1863      Bombus impatiens  1340350.0
# 279        Bombus impatiens Cresson, 1863      Bombus impatiens  1340350.0
# 280  Bombus pensylvanicus (De Geer, 1773)  Bombus pensylvanicus  1340416.0
# 281  Bombus pensylvanicus (De Geer, 1773)  Bombus pensylvanicus  1340416.0
# 282            Bombus huntii Greene, 1860         Bombus huntii  1340369.0
# 283  Bombus pensylvanicus (De Geer, 1773)  Bombus pensylvanicus  1340416.0
# 284    Bombus griseocollis (DeGeer, 1773)   Bombus griseocollis  1340409.0
# 285    Bombus auricomus (Robertson, 1903)      Bombus auricomus  1340446.0
# 286      Bombus bimaculatus Cresson, 1863    Bombus bimaculatus  1340382.0
# 287        Bombus impatiens Cresson, 1863      Bombus impatiens  1340350.0
# 288      Bombus bimaculatus Cresson, 1863    Bombus bimaculatus  1340382.0
# 289    Bombus griseocollis (DeGeer, 1773)   Bombus griseocollis  1340409.0
# 290    Bombus auricomus (Robertson, 1903)      Bombus auricomus  1340446.0
# 291    Bombus auricomus (Robertson, 1903)      Bombus auricomus  1340446.0
# 292    Bombus auricomus (Robertson, 1903)      Bombus auricomus  1340446.0
# 293    Bombus auricomus (Robertson, 1903)      Bombus auricomus  1340446.0
# 294    Bombus auricomus (Robertson, 1903)      Bombus auricomus  1340446.0
# 295     Bombus fervidus (Fabricius, 1798)       Bombus fervidus  1340478.0
# 296    Bombus griseocollis (DeGeer, 1773)   Bombus griseocollis  1340409.0
# 297    Bombus griseocollis (DeGeer, 1773)   Bombus griseocollis  1340409.0
# 298        Bombus impatiens Cresson, 1863      Bombus impatiens  1340350.0
# 299        Bombus impatiens Cresson, 1863      Bombus impatiens  1340350.0
#
#     specificEpithet stateProvince  taxonKey taxonRank  year
# 0         impatiens      Illinois   1340350   SPECIES  1990
# 1         auricomus      Illinois   1340446   SPECIES  1990
# 2     pensylvanicus      Nebraska   1340416   SPECIES  2000
# 3            vagans      Nebraska   1340472   SPECIES  2000
# 4     pensylvanicus      Nebraska   1340416   SPECIES  2000
# 5         auricomus      Nebraska   1340446   SPECIES  2000
# 6      griseocollis      Nebraska   1340409   SPECIES  2000
# 7         impatiens      Missouri   1340350   SPECIES  1990
# 8         auricomus      Nebraska   1340446   SPECIES  2000
# 9         auricomus      Nebraska   1340446   SPECIES  2000
# 10        auricomus      Nebraska   1340446   SPECIES  2000
# 11         fervidus      Nebraska   1340478   SPECIES  2000
# 12         fervidus      Nebraska   1340478   SPECIES  2000
# 13        centralis      Nebraska   1340324   SPECIES  2000
# 14     griseocollis      Nebraska   1340409   SPECIES  2000
# 15     griseocollis      Nebraska   1340409   SPECIES  2000
# 16        impatiens      Nebraska   1340350   SPECIES  2000
# 17        impatiens      Nebraska   1340350   SPECIES  2000
# 18        impatiens      Nebraska   1340350   SPECIES  2000
# 19        impatiens      Nebraska   1340350   SPECIES  2000
# 20        impatiens      Nebraska   1340350   SPECIES  2000
# 21          affinis     Minnesota   1340481   SPECIES  1990
# 22        auricomus      Missouri   1340446   SPECIES  2000
# 23        impatiens      Missouri   1340350   SPECIES  2000
# 24        impatiens      Missouri   1340350   SPECIES  2000
# 25      bimaculatus      Missouri   1340382   SPECIES  2000
# 26    pensylvanicus   Mississippi   1340416   SPECIES  2000
# 27    pensylvanicus   Mississippi   1340416   SPECIES  2000
# 28      bimaculatus      Nebraska   1340382   SPECIES  2000
# 29        auricomus      Nebraska   1340446   SPECIES  2000
# ..              ...           ...       ...       ...   ...
# 270       auricomus      Nebraska   1340446   SPECIES  2000
# 271       auricomus      Nebraska   1340446   SPECIES  2000
# 272       auricomus      Nebraska   1340446   SPECIES  2000
# 273     bimaculatus      Nebraska   1340382   SPECIES  2000
# 274     bimaculatus      Nebraska   1340382   SPECIES  2000
# 275       auricomus      Nebraska   1340446   SPECIES  2000
# 276    griseocollis      Nebraska   1340409   SPECIES  2000
# 277    griseocollis      Nebraska   1340409   SPECIES  2000
# 278       impatiens      Nebraska   1340350   SPECIES  2000
# 279       impatiens      Nebraska   1340350   SPECIES  2000
# 280   pensylvanicus      Nebraska   1340416   SPECIES  2000
# 281   pensylvanicus      Nebraska   1340416   SPECIES  2000
# 282          huntii      Nebraska   1340369   SPECIES  2000
# 283   pensylvanicus      Maryland   1340416   SPECIES  1990
# 284    griseocollis      Nebraska   1340409   SPECIES  2000
# 285       auricomus      Missouri   1340446   SPECIES  2000
# 286     bimaculatus      Missouri   1340382   SPECIES  2000
# 287       impatiens      Missouri   1340350   SPECIES  2000
# 288     bimaculatus     Minnesota   1340382   SPECIES  1990
# 289    griseocollis      Nebraska   1340409   SPECIES  2000
# 290       auricomus      Nebraska   1340446   SPECIES  2000
# 291       auricomus      Nebraska   1340446   SPECIES  2000
# 292       auricomus      Nebraska   1340446   SPECIES  2000
# 293       auricomus      Nebraska   1340446   SPECIES  2000
# 294       auricomus      Nebraska   1340446   SPECIES  2000
# 295        fervidus      Nebraska   1340478   SPECIES  2000
# 296    griseocollis      Nebraska   1340409   SPECIES  2000
# 297    griseocollis      Nebraska   1340409   SPECIES  2000
# 298       impatiens      Nebraska   1340350   SPECIES  2000
# 299       impatiens      Nebraska   1340350   SPECIES  2000
#
# [300 rows x 53 columns]

# %% [markdown]
# ### Task 3:
# I will post a working example on Friday so that you can *update or fix your code before the next class to ensure your code is working*. Then push your updated/fixed code to GitHub before the next class. You should hopefully be able to get it working, since you've done all of these tasks before. We are going to continue adding new functions to this library over the next two weeks, so if you get stuck on this assignment ask for help and try to keep up, because it will be very difficult if you get behind.
